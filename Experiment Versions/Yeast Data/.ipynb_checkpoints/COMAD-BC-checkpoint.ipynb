# %%
# Import Modules

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
import seaborn as sns
import statistics
import fastcluster
from scipy import stats
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from mpl_toolkits.mplot3d import Axes3D
from itertools import combinations
from itertools import permutations
from scipy.spatial.distance import pdist, squareform
from mpl_toolkits.mplot3d import Axes3D

# %%
bc = pd.read_csv('breastcancerdata.csv')
bc_noindex = pd.read_csv('breastcancerdata.csv', index_col=False) 
bc_noindex = bc_noindex.drop('Unnamed: 32', axis=1)
bc_columns = bc_noindex.columns

categorical_features = ['id','diagnosis']
numerical_features = ['radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']
cat_data = bc_noindex[categorical_features]

scaler = MinMaxScaler(feature_range=(-1, 1))
x = pd.DataFrame(scaler.fit_transform(bc_noindex[numerical_features]))
x.columns = numerical_features
x_comb = pd.concat([cat_data, x], axis=1)
print(f'\n----> SCALED DATASET : \n\n{x_comb}')
s_row, s_col = x.shape


print(f'\n*\tSamples : {s_row}, Dimensions : {len(bc_noindex.columns)}')

#sns.pairplot(data=x_comb, hue='diagnosis', height=2)
#plt.plot()
# Out:
# ----> SCALED DATASET :
#
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M     0.042075     -0.954684        0.091977  -0.272534
# 1      842517         M     0.286289     -0.454853        0.231567   0.003181
# 2    84300903         M     0.202991     -0.219479        0.191486  -0.101166
# 3    84348301         M    -0.579819     -0.278323       -0.532997  -0.794189
# 4    84358402         M     0.259785     -0.686845        0.261972  -0.021421
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M     0.379999     -0.142374        0.357335   0.132980
# 565    926682         M     0.244640      0.253974        0.208071  -0.051962
# 566    926954         M    -0.089498      0.242475       -0.108424  -0.393765
# 567    927241         M     0.289129      0.327021        0.331076  -0.048568
# 568     92751         B    -0.926262      0.003044       -0.942920  -0.968187
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.187506          0.584075        0.406279             0.462227
# 1          -0.420240         -0.636464       -0.592784            -0.302485
# 2           0.028618         -0.137967       -0.074977             0.271372
# 3           0.622642          0.622723        0.131209             0.045726
# 4          -0.139298         -0.304214       -0.072165             0.036779
# ..               ...               ...             ...                  ...
# 564         0.053895         -0.407889        0.142924             0.380716
# 565        -0.184436         -0.484571       -0.325211            -0.026740
# 566        -0.423671         -0.491320       -0.566495            -0.472962
# 567         0.176672          0.580394        0.646673             0.510934
# 568        -1.000000         -0.851297       -1.000000            -1.000000
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0    ...      0.241551      -0.716951         0.336620   -0.098604
# 1    ...      0.213803      -0.392857         0.079635   -0.129571
# 2    ...      0.112771      -0.279851         0.016883   -0.250983
# 3    ...     -0.503380      -0.228145        -0.517307   -0.811984
# 4    ...      0.039488      -0.752132         0.013895   -0.316850
# ..   ...           ...            ...              ...         ...
# 564  ...      0.246531      -0.233475         0.152348   -0.094672
# 565  ...      0.121309       0.398188         0.041785   -0.240169
# 566  ...     -0.213803       0.178038        -0.240102   -0.538537
# 567  ...      0.267165       0.460554         0.336620   -0.195930
# 568  ...     -0.891427      -0.021855        -0.912844   -0.959005
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0            0.202272           0.238583         0.137220
# 1           -0.304893          -0.690873        -0.614058
# 2           -0.032820          -0.229250        -0.280511
# 3            0.830945           0.628023         0.097284
# 4           -0.125272          -0.655170        -0.361022
# ..                ...                ...              ...
# 564         -0.077726          -0.642945        -0.343930
# 565         -0.399987          -0.680007        -0.486422
# 566         -0.435647          -0.452591        -0.456390
# 567          0.239252           0.631516         0.499521
# 568         -0.751833          -0.927914        -1.000000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.824055        0.196925                -0.162272
# 1                0.278351       -0.532821                -0.554244
# 2                0.670103       -0.192588                -0.573134
# 3                0.769759        1.000000                 0.547422
# 4                0.116838       -0.684999                -0.714810
# ..                    ...             ...                      ...
# 564              0.523024       -0.804849                -0.788666
# 565              0.118900       -0.602996                -0.851371
# 566             -0.025430       -0.742559                -0.696183
# 567              0.821306       -0.005717                -0.095369
# 568             -1.000000       -0.485117                -0.798636
#
# [569 rows x 32 columns]
#
# *	Samples : 569, Dimensions : 32

# %%
## ----------- MEDIAN ABSOLUTE DEVIATION (MAD) correlation matrix ---------------

def compute_median_absolute_deviation(df):
    return df.apply(lambda col: np.absolute(col - col.median()))

def generate_corr_elems(columns):
    comb = permutations(columns, 2)
    perms = list(comb)
    diag = [(col, col) for col in columns]
    return diag + perms

def compute_corr_matrix_values(df, corr_elems):
    corr_values = []
    for elem in corr_elems:
        corr_values.append(df[elem[0]].append(df[elem[1]], ignore_index=True).median(axis=0))
    return corr_values

def construct_corr_matrix(corr_values, num_columns):
    matrix = np.diag(corr_values[:num_columns])
    k = 0
    for i in range(num_columns):
        for j in range(num_columns):
            if i != j:
                matrix[i, j] = corr_values[num_columns:][k]
                k += 1
    return matrix

# Compute the Median Absolute Deviation
x_MAD = compute_median_absolute_deviation(x)
print(f'\n ---> Median Absolute Deviation : \n\n{x_MAD}')

# Generate the correlation matrix elements
corr_elems = generate_corr_elems(x_MAD.columns)
print(f'\n ---> The elements of the corr matrix are : \n\n{corr_elems}')

# Compute the correlation matrix values
corr_values = compute_corr_matrix_values(x_MAD, corr_elems)
print(f'\n ---> The values of the corr_elems are : \n')
for i, value in zip(corr_elems, corr_values):
    print(f'*The median of the columns ({i[0]},{i[1]}) -> {value}')

# Construct the correlation matrix
corr_matrix = construct_corr_matrix(corr_values, x_MAD.shape[1])
print(f'\n ---> Correlation matrix : \n\n{corr_matrix}')
# Out:
#  ---> Median Absolute Deviation :
#
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       0.437314      0.572202        0.505286   0.381676         0.406789
# 1       0.681528      0.072371        0.644876   0.657391         0.200957
# 2       0.598230      0.163003        0.604796   0.553043         0.247901
# 3       0.184580      0.104160        0.119688   0.139979         0.841925
# 4       0.655024      0.304363        0.675282   0.632789         0.079986
# ..           ...           ...             ...        ...              ...
# 564     0.775238      0.240108        0.770645   0.787190         0.273179
# 565     0.639879      0.636456        0.621381   0.602248         0.034847
# 566     0.305741      0.624958        0.304886   0.260445         0.204387
# 567     0.684367      0.709503        0.744385   0.605642         0.395956
# 568     0.531024      0.385526        0.529611   0.313977         0.780717
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0            1.134716        1.117901             1.129225       0.633333
# 1            0.085823        0.118838             0.364513       0.020202
# 2            0.412674        0.636645             0.938370       0.279798
# 3            1.173364        0.842830             0.712724       0.813131
# 4            0.246427        0.639456             0.703777       0.017172
# ..                ...             ...                  ...            ...
# 564          0.142752        0.854545             1.047714       0.066667
# 565          0.066070        0.386410             0.640258       0.040404
# 566          0.059322        0.145127             0.194036       0.204040
# 567          1.131035        1.358294             1.177932       0.611111
# 568          0.300656        0.288379             0.333002       0.207071
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                  0.723252  ...      0.740662       0.430704
# 1                  0.205139  ...      0.712914       0.106610
# 2                  0.065291  ...      0.611882       0.006397
# 3                  1.512216  ...      0.004269       0.058102
# 4                  0.114153  ...      0.538598       0.465885
# ..                      ...  ...           ...            ...
# 564                0.223673  ...      0.745642       0.052772
# 565                0.261584  ...      0.620420       0.684435
# 566                0.213142  ...      0.285308       0.464286
# 567                0.363100  ...      0.766275       0.746802
# 568                0.113732  ...      0.392316       0.264392
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           0.865979    0.654984          0.408109           0.880364
# 1           0.608994    0.624017          0.099056           0.049092
# 2           0.546242    0.502605          0.173017           0.412531
# 3           0.012052    0.058396          1.036783           1.269804
# 4           0.543254    0.436738          0.080565           0.013389
# ..               ...         ...               ...                ...
# 564         0.681707    0.658917          0.128112           0.001164
# 565         0.571144    0.513419          0.194149           0.038226
# 566         0.289257    0.215051          0.229809           0.189190
# 567         0.865979    0.557658          0.445090           1.273297
# 568         0.383485    0.205417          0.545995           0.286133
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.775080              1.137251        0.701360
# 1           0.023802              0.591546        0.028386
# 2           0.357348              0.983299        0.311847
# 3           0.735144              1.082955        1.504435
# 4           0.276837              0.430034        0.180564
# ..               ...                   ...             ...
# 564         0.293930              0.836220        0.300414
# 565         0.151438              0.432096        0.098561
# 566         0.181470              0.287766        0.238123
# 567         1.137380              1.134502        0.498719
# 568         0.362141              0.686804        0.019318
#
#      fractal_dimension_worst
# 0                   0.509773
# 1                   0.117801
# 2                   0.098911
# 3                   1.219467
# 4                   0.042765
# ..                       ...
# 564                 0.116621
# 565                 0.179326
# 566                 0.024137
# 567                 0.576676
# 568                 0.126591
#
# [569 rows x 30 columns]
#
#  ---> The elements of the corr matrix are :
#
# [('radius_mean', 'radius_mean'), ('texture_mean', 'texture_mean'), ('perimeter_mean', 'perimeter_mean'), ('area_mean', 'area_mean'), ('smoothness_mean', 'smoothness_mean'), ('compactness_mean', 'compactness_mean'), ('concavity_mean', 'concavity_mean'), ('concave points_mean', 'concave points_mean'), ('symmetry_mean', 'symmetry_mean'), ('fractal_dimension_mean', 'fractal_dimension_mean'), ('radius_se', 'radius_se'), ('texture_se', 'texture_se'), ('perimeter_se', 'perimeter_se'), ('area_se', 'area_se'), ('smoothness_se', 'smoothness_se'), ('compactness_se', 'compactness_se'), ('concavity_se', 'concavity_se'), ('concave points_se', 'concave points_se'), ('symmetry_se', 'symmetry_se'), ('fractal_dimension_se', 'fractal_dimension_se'), ('radius_worst', 'radius_worst'), ('texture_worst', 'texture_worst'), ('perimeter_worst', 'perimeter_worst'), ('area_worst', 'area_worst'), ('smoothness_worst', 'smoothness_worst'), ('compactness_worst', 'compactness_worst'), ('concavity_worst', 'concavity_worst'), ('concave points_worst', 'concave points_worst'), ('symmetry_worst', 'symmetry_worst'), ('fractal_dimension_worst', 'fractal_dimension_worst'), ('radius_mean', 'texture_mean'), ('radius_mean', 'perimeter_mean'), ('radius_mean', 'area_mean'), ('radius_mean', 'smoothness_mean'), ('radius_mean', 'compactness_mean'), ('radius_mean', 'concavity_mean'), ('radius_mean', 'concave points_mean'), ('radius_mean', 'symmetry_mean'), ('radius_mean', 'fractal_dimension_mean'), ('radius_mean', 'radius_se'), ('radius_mean', 'texture_se'), ('radius_mean', 'perimeter_se'), ('radius_mean', 'area_se'), ('radius_mean', 'smoothness_se'), ('radius_mean', 'compactness_se'), ('radius_mean', 'concavity_se'), ('radius_mean', 'concave points_se'), ('radius_mean', 'symmetry_se'), ('radius_mean', 'fractal_dimension_se'), ('radius_mean', 'radius_worst'), ('radius_mean', 'texture_worst'), ('radius_mean', 'perimeter_worst'), ('radius_mean', 'area_worst'), ('radius_mean', 'smoothness_worst'), ('radius_mean', 'compactness_worst'), ('radius_mean', 'concavity_worst'), ('radius_mean', 'concave points_worst'), ('radius_mean', 'symmetry_worst'), ('radius_mean', 'fractal_dimension_worst'), ('texture_mean', 'radius_mean'), ('texture_mean', 'perimeter_mean'), ('texture_mean', 'area_mean'), ('texture_mean', 'smoothness_mean'), ('texture_mean', 'compactness_mean'), ('texture_mean', 'concavity_mean'), ('texture_mean', 'concave points_mean'), ('texture_mean', 'symmetry_mean'), ('texture_mean', 'fractal_dimension_mean'), ('texture_mean', 'radius_se'), ('texture_mean', 'texture_se'), ('texture_mean', 'perimeter_se'), ('texture_mean', 'area_se'), ('texture_mean', 'smoothness_se'), ('texture_mean', 'compactness_se'), ('texture_mean', 'concavity_se'), ('texture_mean', 'concave points_se'), ('texture_mean', 'symmetry_se'), ('texture_mean', 'fractal_dimension_se'), ('texture_mean', 'radius_worst'), ('texture_mean', 'texture_worst'), ('texture_mean', 'perimeter_worst'), ('texture_mean', 'area_worst'), ('texture_mean', 'smoothness_worst'), ('texture_mean', 'compactness_worst'), ('texture_mean', 'concavity_worst'), ('texture_mean', 'concave points_worst'), ('texture_mean', 'symmetry_worst'), ('texture_mean', 'fractal_dimension_worst'), ('perimeter_mean', 'radius_mean'), ('perimeter_mean', 'texture_mean'), ('perimeter_mean', 'area_mean'), ('perimeter_mean', 'smoothness_mean'), ('perimeter_mean', 'compactness_mean'), ('perimeter_mean', 'concavity_mean'), ('perimeter_mean', 'concave points_mean'), ('perimeter_mean', 'symmetry_mean'), ('perimeter_mean', 'fractal_dimension_mean'), ('perimeter_mean', 'radius_se'), ('perimeter_mean', 'texture_se'), ('perimeter_mean', 'perimeter_se'), ('perimeter_mean', 'area_se'), ('perimeter_mean', 'smoothness_se'), ('perimeter_mean', 'compactness_se'), ('perimeter_mean', 'concavity_se'), ('perimeter_mean', 'concave points_se'), ('perimeter_mean', 'symmetry_se'), ('perimeter_mean', 'fractal_dimension_se'), ('perimeter_mean', 'radius_worst'), ('perimeter_mean', 'texture ...
#
#  ---> The values of the corr_elems are :
#
# *The median of the columns (radius_mean,radius_mean) -> 0.17984760282076762
# *The median of the columns (texture_mean,texture_mean) -> 0.19005749070003386
# *The median of the columns (perimeter_mean,perimeter_mean) -> 0.17566166816391382
# *The median of the columns (area_mean,area_mean) -> 0.1300530222693531
# *The median of the columns (smoothness_mean,smoothness_mean) -> 0.17152658662092635
# *The median of the columns (compactness_mean,compactness_mean) -> 0.2001717686031531
# *The median of the columns (concavity_mean,concavity_mean) -> 0.1895970009372071
# *The median of the columns (concave points_mean,concave points_mean) -> 0.2001988071570575
# *The median of the columns (symmetry_mean,symmetry_mean) -> 0.17272727272727284
# *The median of the columns (fractal_dimension_mean,fractal_dimension_mean) -> 0.17775905644481904
# *The median of the columns (radius_se,radius_se) -> 0.07676987144667757
# *The median of the columns (texture_se,texture_se) -> 0.1393652758132955
# *The median of the columns (perimeter_se,perimeter_se) -> 0.0725627856570702
# *The median of the columns (area_se,area_se) -> 0.03432960153007669
# *The median of the columns (smoothness_se,smoothness_se) -> 0.09865044022164038
# *The median of the columns (compactness_se,compactness_se) -> 0.13158290023132158
# *The median of the columns (concavity_se,concavity_se) -> 0.06303030303030299
# *The median of the columns (concave points_se,concave points_se) -> 0.1320325819283955
# *The median of the columns (symmetry_se,symmetry_se) -> 0.11059830021950812
# *The median of the columns (fractal_dimension_se,fractal_dimension_se) -> 0.07420919530699388
# *The median of the columns (radius_worst,radius_worst) -> 0.17502668089647822
# *The median of the columns (texture_worst,texture_worst) -> 0.2308102345415779
# *The median of the columns (perimeter_worst,perimeter_worst) -> 0.16803625678569645
# *The median of the columns (area_worst,area_worst) -> 0.10597719229256786
# *The median of the columns (smoothness_worst,smoothness_worst) -> 0.19414911180083227
# *The median of the columns (compactness_worst,compactness_worst) -> 0.16900971175209323
# *The median of the columns (concavity_worst,concavity_worst) -> 0.21086261980830667
# *The median of the columns (concave points_worst,concave points_worst) -> 0.3063230240549828
# *The median of the columns (symmetry_worst,symmetry_worst) -> 0.1348314606741573
# *The median of the columns (fractal_dimension_worst,fractal_dimension_worst) -> 0.12934540207267498
# *The median of the columns (radius_mean,texture_mean) -> 0.18461351787951608
# *The median of the columns (radius_mean,perimeter_mean) -> 0.17812103993082962
# *The median of the columns (radius_mean,area_mean) -> 0.15278897136797448
# *The median of the columns (radius_mean,smoothness_mean) -> 0.17558805433290747
# *The median of the columns (radius_mean,compactness_mean) -> 0.18722777743696722
# *The median of the columns (radius_mean,concavity_mean) -> 0.18430178069353326
# *The median of the columns (radius_mean,concave points_mean) -> 0.19070576540755463
# *The median of the columns (radius_mean,symmetry_mean) -> 0.17511477116758956
# *The median of the columns (radius_mean,fractal_dimension_mean) -> 0.17839090143218184
# *The median of the columns (radius_mean,radius_se) -> 0.11095986273399983
# *The median of the columns (radius_mean,texture_se) -> 0.1552775813295615
# *The median of the columns (radius_mean,perimeter_se) -> 0.1059220056148737
# *The median of the columns (radius_mean,area_se) -> 0.08424440342657014
# *The median of the columns (radius_mean,smoothness_se) -> 0.13159864539237198
# *The median of the columns (radius_mean,compactness_se) -> 0.15145061290169926
# *The median of the columns (radius_mean,concavity_se) -> 0.10034225794793017
# *The median of the columns (radius_mean,concave points_se) -> 0.15381701079749954
# *The median of the columns (radius_mean,symmetry_se) -> 0.14026035097280487
# *The median of the columns (radius_mean,fractal_dimension_se) -> 0.10550972181916185
# *The median of the columns (radius_mean,radius_worst) -> 0.1775168979011028
# *The median of the columns (radius_mean,texture_worst) -> 0.1997254957641157
# *The median of the columns (radius_mean,perimeter_worst) -> 0.17558805433290747
# *The median of the columns (radius_mean,area_worst) -> 0.14147377283565687
# *The median of the columns (radius_mean,smoothness_worst) -> 0.18587582953126125
# *The median of the columns (radius_mean,compactness_worst) -> 0.17354118763999932
# *The median of the columns (radius_mean,concavity_worst) -> 0.19422752173360142
# *The median of the columns (radius_mean,concave points_worst) -> 0.2395189003436426
# *The median of the columns (radius_mean,symmetry_worst) -> 0.15248481078707216
# *The median of the columns (radius_mean,fractal_dimension_worst) -> 0.15282697100878917
# *The median of the columns (texture_mean,radius_mean) -> 0.18461351787951608
# *The median of the columns (texture_mean,perimeter_mean) -> 0.183478451544676
# *The median of the columns (texture_mean,area_mean) -> 0.15748112482521665
# *The median of the columns (texture_mean,smoothness_mean) -> 0.1822793371660466
# *The median of the columns (texture_mean,compactness_mean) -> 0.1943132323170358
# *The median of the columns (texture_mean,concavity_mean) -> 0.18982724581862048
# *The median of the columns (texture_mean,concave points_mean) -> 0.19466241105951365
# *The median of the columns (texture_mean,symmetry_mean) -> 0.1798550264224935
# *The median of the columns (texture_mean,fractal_dimension_mean) -> 0.18381325821754613
# *The median of the columns (texture_mean,radius_se) -> 0.11305189091199208
# *The median of the columns (texture_mean,texture_se) -> 0.16199611032531835
# *The median of the columns (texture_mean,perimeter_se) -> 0.10652688535678068
# *The median of the columns (texture_mean,area_se) -> 0.08623605005072721
# *The median of the columns (texture_mean,smoothness_se) -> 0.13257640140055071
# *The median of the columns (texture_mean,compactness_se) -> 0.15363613115839414
# *The median of the columns (texture_mean,concavity_se) -> 0.10053030303030297
# *The median of the columns (texture_mean,concave points_se) -> 0.1587109304207054
# *The median of the columns (texture_mean,symmetry_se) -> 0.14221733821631577
# *The median of the columns (texture_mean,fractal_dimension_se) -> 0.10595884637176456
# *The median of the columns (texture_mean,radius_worst) -> 0.18285307719672717
# *The median of the columns (texture_mean,texture_worst) -> 0.20508065859407731
# *The median of the columns (texture_mean,perimeter_worst) -> 0.1812743619416191
# *The median of the columns (texture_mean,area_worst) -> 0.14436337371242347
# *The median of the columns (texture_mean,smoothness_worst) -> 0.19276293540750744
# *The median of the columns (texture_mean,compactness_worst) -> 0.1805884342238755
# *The median of the columns (texture_mean,concavity_worst) -> 0.19854649875046054
# *The median of the columns (texture_mean,concave points_worst) -> 0.23950428071545526
# *The median of the columns (texture_mean,symmetry_worst) -> 0.15533215060122219
# *The median of the columns (texture_mean,fractal_dimension_worst) -> 0.15537565838854006
# *The median of the columns (perimeter_mean,radius_mean) -> 0.17812103993082962
# *The median of the columns (perimeter_mean,texture_mean) -> 0.183478451544676
# *The median of the columns (perimeter_mean,area_mean) -> 0.1523347012157933
# *The median of the columns (perimeter_mean,smoothness_mean) -> 0.1733121415244282
# *The median of the columns (perimeter_mean,compactness_mean) -> 0.18722777743696722
# *The median of the columns (perimeter_mean,concavity_mean) -> 0.18334114339268975
# *The median of the columns (perimeter_mean,concave points_mean) -> 0.19070576540755463
# *The median of the columns (perimeter_mean,symmetry_mean) -> 0.17380117252966398
# *The median of the columns (perimeter_mean,fractal_dimension_mean) -> 0.1773256881831523
# *The median of the columns (perimeter_mean,radius_se) -> 0.11214919427847181
# *The median of the columns (perimeter_mean,texture_se) -> 0.1549493630728267
# *The median of the columns (perimeter_mean,perimeter_se) -> 0.10776044856994776
# *The median of the columns (perimeter_mean,area_se) -> 0.08361550687582076
# *The median of the columns (perimeter_mean,smoothness_se) -> 0.13131862528469934
# *The median of the columns (perimeter_mean,compactness_se) -> 0.15141046054015073
# *The median of the columns (perimeter_mean,concavity_se) -> 0.10213530509294455
# *The median of the columns (perimeter_mean,concave points_se) -> 0.15381701079749954
# *The median of the columns (perimeter_mean,symmetry_se) -> 0.13917245117842464
# *The median of the columns (perimeter_mean,fractal_dimension_se) -> 0.10693209703071316
# *The median of the columns (perimeter_mean,radius_worst) -> 0.1754543569898417
# *The median of the columns (perimeter_mean,texture_worst) -> 0.20309168443496806
# *The median of the columns (perimeter_mean,perimeter_worst) -> 0.1733121415244282
# *The median of the columns (perimeter_mean,area_worst) -> 0.14009182174402096
# *The median of the columns (perimeter_mean,smoothness_worst) -> 0.1855642871293669
# *The median of the columns (perimeter_mean,compactness_worst) -> 0.17275931172690207
# *The median of the columns (perimeter_mean,concavity_worst) -> 0.19443341348335091
# *The median of the columns (perimeter_mean,concave points_worst) -> 0.24086091367472456
# *The median of the columns (perimeter_mean,symmetry_worst) -> 0.1520442817430644
# *The median of the columns (perimeter_mean,fractal_dimension_worst) -> 0.15230460921843703
# *The median of the columns (area_mean,radius_mean) -> 0.15278897136797448
# *The median of the columns (area_mean,texture_mean) -> 0.15748112482521665
# *The median of the columns (area_mean,perimeter_mean) -> 0.1523347012157933
# *The median of the columns (area_mean,smoothness_mean) -> 0.15028632025450694
# *The median of the columns (area_mean,compactness_mean) -> 0.15905665703195115
# *The median of the columns (area_mean,concavity_mean) -> 0.1624179943767572
# *The median of the columns (area_mean,concave points_mean) -> 0.15749734888653233
# *The median of the columns (area_mean,symmetry_mean) -> 0.15134676564156957
# *The median of the columns (area_mean,fractal_dimension_mean) -> 0.1481131487187553
# *The median of the columns (area_mean,radius_se) -> 0.09996482846532645
# *The median of the columns (area_mean,texture_se) -> 0.13275724893917967
# *The median of the columns (area_mean,perimeter_se) -> 0.09366054724938017
# *The median of the columns (area_mean,area_se) -> 0.07090052633741628
# *The median of the columns (area_mean,smoothness_se) -> 0.11318529106697062
# *The median of the columns (area_mean,compactness_se) -> 0.1311016618507998
# *The median of the columns (area_mean,concavity_se) -> 0.08903870625662774
# *The median of the columns (area_mean,concave points_se) -> 0.13083198258290268
# *The median of the columns (area_mean,symmetry_se) -> 0.11833736702876119
# *The median of the columns (area_mean,fractal_dimension_se) -> 0.09633085896076354
# *The median of the columns (area_mean,radius_worst) -> 0.14761594448110044
# *The median of the columns (area_mean,texture_worst) -> 0.17340402969247087
# *The median of the columns (area_mean,perimeter_worst) -> 0.1478847333520399
# *The median of the columns (area_mean,area_worst) -> 0.11762907888871327
# *The median of the columns (area_mean,smoothness_worst) -> 0.15342171475342625
# *The median of the columns (area_mean,compactness_worst) -> 0.14502096316705698
# *The median of the columns (area_mean,concavity_worst) -> 0.16629392971246004
# *The median of the columns (area_mean,concave points_worst) -> 0.2067136032185064
# *The median of the columns (area_mean,symmetry_worst) -> 0.1317560394486521
# *The median of the columns (area_mean,fractal_dimension_worst) -> 0.12987674043877662
# *The median of the columns (smoothness_mean,radius_mean) -> 0.17558805433290747
# *The median of the columns (smoothness_mean,texture_mean) -> 0.1822793371660466
# *The median of the columns (smoothness_mean,perimeter_mean) -> 0.1733121415244282
# *The median of the columns (smoothness_mean,area_mean) -> 0.15028632025450694
# *The median of the columns (smoothness_mean,compactness_mean) -> 0.18656345590126755
# *The median of the columns (smoothness_mean,concavity_mean) -> 0.1826850984067479
# *The median of the columns (smoothness_mean,concave points_mean) -> 0.18839366078513115
# *The median of the columns (smoothness_mean,symmetry_mean) -> 0.1720682495260446
# *The median of the columns (smoothness_mean,fractal_dimension_mean) -> 0.17417860151642794
# *The median of the columns (smoothness_mean,radius_se) -> 0.10936085460800288
# *The median of the columns (smoothness_mean,texture_se) -> 0.1524624796764682
# *The median of the columns (smoothness_mean,perimeter_se) -> 0.10419922914466484
# *The median of the columns (smoothness_mean,area_se) -> 0.08124943576780752
# *The median of the columns (smoothness_mean,smoothness_se) -> 0.13054076013360993
# *The median of the columns (smoothness_mean,compactness_se) -> 0.14940868466191226
# *The median of the columns (smoothness_mean,concavity_se) -> 0.0974624146128617
# *The median of the columns (smoothness_mean,concave points_se) -> 0.15206499448666372
# *The median of the columns (smoothness_mean,symmetry_se) -> 0.13888358682893426
# *The median of the columns (smoothness_mean,fractal_dimension_se) -> 0.10345761487767424
# *The median of the columns (smoothness_mean,radius_worst) -> 0.1720682495260446
# *The median of the columns (smoothness_mean,texture_worst) -> 0.19669509594882728
# *The median of the columns (smoothness_mean,perimeter_worst) -> 0.17026270650898256
# *The median of the columns (smoothness_mean,area_worst) -> 0.1395684752189219
# *The median of the columns (smoothness_mean,smoothness_worst) -> 0.1832423406860314
# *The median of the columns (smoothness_mean,compactness_worst) -> 0.17026270650898256
# *The median of the columns (smoothness_mean,concavity_worst) -> 0.19230089489749524
# *The median of the columns (smoothness_mean,concave points_worst) -> 0.22659793814432982
# *The median of the columns (smoothness_mean,symmetry_worst) -> 0.1501309018687369
# *The median of the columns (smoothness_mean,fractal_dimension_worst) -> 0.14931840751105918
# *The median of the columns (compactness_mean,radius_mean) -> 0.18722777743696722
# *The median of the columns (compactness_mean,texture_mean) -> 0.1943132323170358
# *The median of the columns (compactness_mean,perimeter_mean) -> 0.18722777743696722
# *The median of the columns (compactness_mean,area_mean) -> 0.15905665703195115
# *The median of the columns (compactness_mean,smoothness_mean) -> 0.18656345590126755
# *The median of the columns (compactness_mean,concavity_mean) -> 0.19428279795163245
# *The median of the columns (compactness_mean,concave points_mean) -> 0.2001852878801053
# *The median of the columns (compactness_mean,symmetry_mean) -> 0.18244279492055698
# *The median of the columns (compactness_mean,fractal_dimension_mean) -> 0.18697358202397868
# *The median of the columns (compactness_mean,radius_se) -> 0.1188377588762412
# *The median of the columns (compactness_mean,texture_se) -> 0.16199611032531835
# *The median of the columns (compactness_mean,perimeter_se) -> 0.11162418131272672
# *The median of the columns (compactness_mean,area_se) -> 0.09246224176978657
# *The median of the columns (compactness_mean,smoothness_se) -> 0.1353904668425251
# *The median of the columns (compactness_mean,compactness_se) -> 0.15666776819779493
# *The median of the columns (compactness_mean,concavity_se) -> 0.10416313245949471
# *The median of the columns (compactness_mean,concave points_se) -> 0.16057044811894317
# *The median of the columns (compactness_mean,symmetry_se) -> 0.1442280632633534
# *The median of the columns (compactness_mean,fractal_dimension_se) -> 0.11041554385528518
# *The median of the columns (compactness_mean,radius_worst) -> 0.18581927620052252
# *The median of the columns (compactness_mean,texture_worst) -> 0.20978950890425047
# *The median of the columns (compactness_mean,perimeter_worst) -> 0.1838102891529504
# *The median of the columns (compactness_mean,area_worst) -> 0.14600814792392514
# *The median of the columns (compactness_mean,smoothness_worst) -> 0.19713514508312374
# *The median of the columns (compactness_mean,compactness_worst) -> 0.18385663227858617
# *The median of the columns (compactness_mean,concavity_worst) -> 0.20271345002648844
# *The median of the columns (compactness_mean,concave points_worst) -> 0.2395251825041409
# *The median of the columns (compactness_mean,symmetry_worst) -> 0.15752496224891444
# *The median of the columns (compactness_mean,fractal_dimension_worst) -> 0.1578118850846123
# *The median of the columns (concavity_mean,radius_mean) -> 0.18430178069353326
# *The median of the columns (concavity_mean,texture_mean) -> 0.18982724581862048
# *The median of the columns (concavity_mean,perimeter_mean) -> 0.18334114339268975
# *The median of the columns (concavity_mean,area_mean) -> 0.1624179943767572
# *The median of the columns (concavity_mean,smoothness_mean) -> 0.1826850984067479
# *The median of the columns (concavity_mean,compactness_mean) -> 0.19428279795163245
# *The median of the columns (concavity_mean,concave points_mean) -> 0.1944079198659962
# *The median of the columns (concavity_mean,symmetry_mean) -> 0.17870977819431422
# *The median of the columns (concavity_mean,fractal_dimension_mean) -> 0.1835807154830248
# *The median of the columns (concavity_mean,radius_se) -> 0.12006794963754708
# *The median of the columns (concavity_mean,texture_se) -> 0.16335943931285613
# *The median of the columns (concavity_mean,perimeter_se) -> 0.11237808038448854
# *The median of the columns (concavity_mean,area_se) -> 0.09646204311152767
# *The median of the columns (concavity_mean,smoothness_se) -> 0.1409437762065231
# *The median of the columns (concavity_mean,compactness_se) -> 0.15907683423163443
# *The median of the columns (concavity_mean,concavity_se) -> 0.10635499323128184
# *The median of the columns (concavity_mean,concave points_se) -> 0.16248828491096529
# *The median of the columns (concavity_mean,symmetry_se) -> 0.14802955327867146
# *The median of the columns (concavity_mean,fractal_dimension_se) -> 0.11129125708132881
# *The median of the columns (concavity_mean,radius_worst) -> 0.18287452360304962
# *The median of the columns (concavity_mean,texture_worst) -> 0.20443070162642407
# *The median of the columns (concavity_mean,perimeter_worst) -> 0.17993924000199218
# *The median of the columns (concavity_mean,area_worst) -> 0.14897709720824315
# *The median of the columns (concavity_mean,smoothness_worst) -> 0.19287722586691652
# *The median of the columns (concavity_mean,compactness_worst) -> 0.17902999062792874
# *The median of the columns (concavity_mean,concavity_worst) -> 0.19568884723523894
# *The median of the columns (concavity_mean,concave points_worst) -> 0.23814432989690726
# *The median of the columns (concavity_mean,symmetry_worst) -> 0.16126957849326728
# *The median of the columns (concavity_mean,fractal_dimension_worst) -> 0.15879574970484056
# *The median of the columns (concave points_mean,radius_mean) -> 0.19070576540755463
# *The median of the columns (concave points_mean,texture_mean) -> 0.19466241105951365
# *The median of the columns (concave points_mean,perimeter_mean) -> 0.19070576540755463
# *The median of the columns (concave points_mean,area_mean) -> 0.15749734888653233
# *The median of the columns (concave points_mean,smoothness_mean) -> 0.18839366078513115
# *The median of the columns (concave points_mean,compactness_mean) -> 0.2001852878801053
# *The median of the columns (concave points_mean,concavity_mean) -> 0.1944079198659962
# *The median of the columns (concave points_mean,symmetry_mean) -> 0.1837680984798281
# *The median of the columns (concave points_mean,fractal_dimension_mean) -> 0.18941351888667984
# *The median of the columns (concave points_mean,radius_se) -> 0.11687307802649977
# *The median of the columns (concave points_mean,texture_se) -> 0.16089108910891098
# *The median of the columns (concave points_mean,perimeter_se) -> 0.10989765829468362
# *The median of the columns (concave points_mean,area_se) -> 0.09194831013916499
# *The median of the columns (concave points_mean,smoothness_se) -> 0.1376739562624255
# *The median of the columns (concave points_mean,compactness_se) -> 0.15606527566358996
# *The median of the columns (concave points_mean,concavity_se) -> 0.10373290559672271
# *The median of the columns (concave points_mean,concave points_se) -> 0.15816493349055133
# *The median of the columns (concave points_mean,symmetry_se) -> 0.14438369781312133
# *The median of the columns (concave points_mean,fractal_dimension_se) -> 0.1084990059642148
# *The median of the columns (concave points_mean,radius_worst) -> 0.18747776591960164
# *The median of the columns (concave points_mean,texture_worst) -> 0.21341895323157012
# *The median of the columns (concave points_mean,perimeter_worst) -> 0.18467055132227694
# *The median of the columns (concave points_mean,area_worst) -> 0.1457349786456253
# *The median of the columns (concave points_mean,smoothness_worst) -> 0.19776342276526415
# *The median of the columns (concave points_mean,compactness_worst) -> 0.18667992047713727
# *The median of the columns (concave points_mean,concavity_worst) -> 0.20325713450923844
# *The median of the columns (concave points_mean,concave points_worst) -> 0.25164880134997575
# *The median of the columns (concave points_mean,symmetry_worst) -> 0.15619153206132808
# *The median of the columns (concave points_mean,fractal_dimension_worst) -> 0.1563121272365806
# *The median of the columns (symmetry_mean,radius_mean) -> 0.17511477116758956
# *The median of the columns (symmetry_mean,texture_mean) -> 0.1798550264224935
# *The median of the columns (symmetry_mean,perimeter_mean) -> 0.17380117252966398
# *The median of the columns (symmetry_mean,area_mean) -> 0.15134676564156957
# *The median of the columns (symmetry_mean,smoothness_mean) -> 0.1720682495260446
# *The median of the columns (symmetry_mean,compactness_mean) -> 0.18244279492055698
# *The median of the columns (symmetry_mean,concavity_mean) -> 0.17870977819431422
# *The median of the columns (symmetry_mean,concave points_mean) -> 0.1837680984798281
# *The median of the columns (symmetry_mean,fractal_dimension_mean) -> 0.17474747474747487
# *The median of the columns (symmetry_mean,radius_se) -> 0.10987578116855679
# *The median of the columns (symmetry_mean,texture_se) -> 0.15336774748903448
# *The median of the columns (symmetry_mean,perimeter_se) -> 0.10436906881565988
# *The median of the columns (symmetry_mean,area_se) -> 0.07964512268245189
# *The median of the columns (symmetry_mean,smoothness_se) -> 0.1313131313131315
# *The median of the columns (symmetry_mean,compactness_se) -> 0.14975816384774843
# *The median of the columns (symmetry_mean,concavity_se) -> 0.09803030303030297
# *The median of the columns (symmetry_mean,concave points_se) -> 0.1529645766243607
# *The median of the columns (symmetry_mean,symmetry_se) -> 0.13787878787878782
# *The median of the columns (symmetry_mean,fractal_dimension_se) -> 0.1037132236087504
# *The median of the columns (symmetry_mean,radius_worst) -> 0.17323232323232318
# *The median of the columns (symmetry_mean,texture_worst) -> 0.19502272188839365
# *The median of the columns (symmetry_mean,perimeter_worst) -> 0.1702253371908236
# *The median of the columns (symmetry_mean,area_worst) -> 0.1393939393939394
# *The median of the columns (symmetry_mean,smoothness_worst) -> 0.17920441288003852
# *The median of the columns (symmetry_mean,compactness_worst) -> 0.17046501925856933
# *The median of the columns (symmetry_mean,concavity_worst) -> 0.18786910639945792
# *The median of the columns (symmetry_mean,concave points_worst) -> 0.22854003957096752
# *The median of the columns (symmetry_mean,symmetry_worst) -> 0.1513897102306328
# *The median of the columns (symmetry_mean,fractal_dimension_worst) -> 0.15043945953036852
# *The median of the columns (fractal_dimension_mean,radius_mean) -> 0.17839090143218184
# *The median of the columns (fractal_dimension_mean,texture_mean) -> 0.18381325821754613
# *The median of the columns (fractal_dimension_mean,perimeter_mean) -> 0.1773256881831523
# *The median of the columns (fractal_dimension_mean,area_mean) -> 0.1481131487187553
# *The median of the columns (fractal_dimension_mean,smoothness_mean) -> 0.17417860151642794
# *The median of the columns (fractal_dimension_mean,compactness_mean) -> 0.18697358202397868
# *The median of the columns (fractal_dimension_mean,concavity_mean) -> 0.1835807154830248
# *The median of the columns (fractal_dimension_mean,concave points_mean) -> 0.18941351888667984
# *The median of the columns (fractal_dimension_mean,symmetry_mean) -> 0.17474747474747487
# *The median of the columns (fractal_dimension_mean,radius_se) -> 0.10783487784330248
# *The median of the columns (fractal_dimension_mean,texture_se) -> 0.15284653465346526
# *The median of the columns (fractal_dimension_mean,perimeter_se) -> 0.10378320622335119
# *The median of the columns (fractal_dimension_mean,area_se) -> 0.07674664455227698
# *The median of the columns (fractal_dimension_mean,smoothness_se) -> 0.12502688085126568
# *The median of the columns (fractal_dimension_mean,compactness_se) -> 0.14765524078469072
# *The median of the columns (fractal_dimension_mean,concavity_se) -> 0.09766570932577673
# *The median of the columns (fractal_dimension_mean,concave points_se) -> 0.15199336979684414
# *The median of the columns (fractal_dimension_mean,symmetry_se) -> 0.1341642891327215
# *The median of the columns (fractal_dimension_mean,fractal_dimension_se) -> 0.10281497450354471
# *The median of the columns (fractal_dimension_mean,radius_worst) -> 0.1770388745381979
# *The median of the columns (fractal_dimension_mean,texture_worst) -> 0.1973925055191007
# *The median of the columns (fractal_dimension_mean,perimeter_worst) -> 0.17417860151642794
# *The median of the columns (fractal_dimension_mean,area_worst) -> 0.13406901297679907
# *The median of the columns (fractal_dimension_mean,smoothness_worst) -> 0.1849199663016008
# *The median of the columns (fractal_dimension_mean,compactness_worst) -> 0.17271696765213113
# *The median of the columns (fractal_dimension_mean,concavity_worst) -> 0.19188708344660343
# *The median of the columns (fractal_dimension_mean,concave points_worst) -> 0.22872788542544242
# *The median of the columns (fractal_dimension_mean,symmetry_worst) -> 0.14902424600827913
# *The median of the columns (fractal_dimension_mean,fractal_dimension_worst) -> 0.14736007102170845
# *The median of the columns (radius_se,radius_mean) -> 0.11095986273399983
# *The median of the columns (radius_se,texture_mean) -> 0.11305189091199208
# *The median of the columns (radius_se,perimeter_mean) -> 0.11214919427847181
# *The median of the columns (radius_se,area_mean) -> 0.09996482846532645
# *The median of the columns (radius_se,smoothness_mean) -> 0.10936085460800288
# *The median of the columns (radius_se,compactness_mean) -> 0.1188377588762412
# *The median of the columns (radius_se,concavity_mean) -> 0.12006794963754708
# *The median of the columns (radius_se,concave points_mean) -> 0.11687307802649977
# *The median of the columns (radius_se,symmetry_mean) -> 0.10987578116855679
# *The median of the columns (radius_se,fractal_dimension_mean) -> 0.10783487784330248
# *The median of the columns (radius_se,texture_se) -> 0.1010136279787675
# *The median of the columns (radius_se,perimeter_se) -> 0.07494989725215956
# *The median of the columns (radius_se,area_se) -> 0.053434851764111446
# *The median of the columns (radius_se,smoothness_se) -> 0.08426579757378239
# *The median of the columns (radius_se,compactness_se) -> 0.10065490760565654
# *The median of the columns (radius_se,concavity_se) -> 0.07074381786358974
# *The median of the columns (radius_se,concave points_se) -> 0.09736692555408222
# *The median of the columns (radius_se,symmetry_se) -> 0.09160757266942082
# *The median of the columns (radius_se,fractal_dimension_se) -> 0.07591868799738244
# *The median of the columns (radius_se,radius_worst) -> 0.10899873257287701
# *The median of the columns (radius_se,texture_worst) -> 0.12416793004018473
# *The median of the columns (radius_se,perimeter_worst) -> 0.10955907760218941
# *The median of the columns (radius_se,area_worst) -> 0.0875901931998665
# *The median of the columns (radius_se,smoothness_worst) -> 0.11622531862906949
# *The median of the columns (radius_se,compactness_worst) -> 0.1056127571597269
# *The median of the columns (radius_se,concavity_worst) -> 0.12388194821654891
# *The median of the columns (radius_se,concave points_worst) -> 0.13982082425694986
# *The median of the columns (radius_se,symmetry_worst) -> 0.09928546748166606
# *The median of the columns (radius_se,fractal_dimension_worst) -> 0.09753377935196123
# *The median of the columns (texture_se,radius_mean) -> 0.1552775813295615
# *The median of the columns (texture_se,texture_mean) -> 0.16199611032531835
# *The median of the columns (texture_se,perimeter_mean) -> 0.1549493630728267
# *The median of the columns (texture_se,area_mean) -> 0.13275724893917967
# *The median of the columns (texture_se,smoothness_mean) -> 0.1524624796764682
# *The median of the columns (texture_se,compactness_mean) -> 0.16199611032531835
# *The median of the columns (texture_se,concavity_mean) -> 0.16335943931285613
# *The median of the columns (texture_se,concave points_mean) -> 0.16089108910891098
# *The median of the columns (texture_se,symmetry_mean) -> 0.15336774748903448
# *The median of the columns (texture_se,fractal_dimension_mean) -> 0.15284653465346526
# *The median of the columns (texture_se,radius_se) -> 0.1010136279787675
# *The median of the columns (texture_se,perimeter_se) -> 0.09498361771552183
# *The median of the columns (texture_se,area_se) -> 0.07072135785007078
# *The median of the columns (texture_se,smoothness_se) -> 0.11561342081109566
# *The median of the columns (texture_se,compactness_se) -> 0.13336087993286627
# *The median of the columns (texture_se,concavity_se) -> 0.0892975601131541
# *The median of the columns (texture_se,concave points_se) -> 0.1334604627553384
# *The median of the columns (texture_se,symmetry_se) -> 0.12242715833487844
# *The median of the columns (texture_se,fractal_dimension_se) -> 0.09663087489462846
# *The median of the columns (texture_se,radius_worst) -> 0.15154749199573114
# *The median of the columns (texture_se,texture_worst) -> 0.17054897454031115
# *The median of the columns (texture_se,perimeter_worst) -> 0.15213932107496464
# *The median of the columns (texture_se,area_worst) -> 0.12108650413732452
# *The median of the columns (texture_se,smoothness_worst) -> 0.15801803394625186
# *The median of the columns (texture_se,compactness_worst) -> 0.14882944766229111
# *The median of the columns (texture_se,concavity_worst) -> 0.1666865688166262
# *The median of the columns (texture_se,concave points_worst) -> 0.19753359264497877
# *The median of the columns (texture_se,symmetry_worst) -> 0.13621131480386367
# *The median of the columns (texture_se,fractal_dimension_worst) -> 0.13228295232120613
# *The median of the columns (perimeter_se,radius_mean) -> 0.1059220056148737
# *The median of the columns (perimeter_se,texture_mean) -> 0.10652688535678068
# *The median of the columns (perimeter_se,perimeter_mean) -> 0.10776044856994776
# *The median of the columns (perimeter_se,area_mean) -> 0.09366054724938017
# *The median of the columns (perimeter_se,smoothness_mean) -> 0.10419922914466484
# *The median of the columns (perimeter_se,compactness_mean) -> 0.11162418131272672
# *The median of the columns (perimeter_se,concavity_mean) -> 0.11237808038448854
# *The median of the columns (perimeter_se,concave points_mean) -> 0.10989765829468362
# *The median of the columns (perimeter_se,symmetry_mean) -> 0.10436906881565988
# *The median of the columns (perimeter_se,fractal_dimension_mean) -> 0.10378320622335119
# *The median of the columns (perimeter_se,radius_se) -> 0.07494989725215956
# *The median of the columns (perimeter_se,texture_se) -> 0.09498361771552183
# *The median of the columns (perimeter_se,area_se) -> 0.05016996484142322
# *The median of the columns (perimeter_se,smoothness_se) -> 0.08043160721858356
# *The median of the columns (perimeter_se,compactness_se) -> 0.09627808748492028
# *The median of the columns (perimeter_se,concavity_se) -> 0.06799227253451445
# *The median of the columns (perimeter_se,concave points_se) -> 0.09282382321066768
# *The median of the columns (perimeter_se,symmetry_se) -> 0.08773500447627575
# *The median of the columns (perimeter_se,fractal_dimension_se) -> 0.07293973519295105
# *The median of the columns (perimeter_se,radius_worst) -> 0.1046434238925763
# *The median of the columns (perimeter_se,texture_worst) -> 0.11543105013298222
# *The median of the columns (perimeter_se,perimeter_worst) -> 0.10502756443481132
# *The median of the columns (perimeter_se,area_worst) -> 0.08438957734533287
# *The median of the columns (perimeter_se,smoothness_worst) -> 0.11072892616500968
# *The median of the columns (perimeter_se,compactness_worst) -> 0.09989162700843429
# *The median of the columns (perimeter_se,concavity_worst) -> 0.11408948998757912
# *The median of the columns (perimeter_se,concave points_worst) -> 0.1272852233676976
# *The median of the columns (perimeter_se,symmetry_worst) -> 0.09384525762718388
# *The median of the columns (perimeter_se,fractal_dimension_worst) -> 0.09146915927081528
# *The median of the columns (area_se,radius_mean) -> 0.08424440342657014
# *The median of the columns (area_se,texture_mean) -> 0.08623605005072721
# *The median of the columns (area_se,perimeter_mean) -> 0.08361550687582076
# *The median of the columns (area_se,area_mean) -> 0.07090052633741628
# *The median of the columns (area_se,smoothness_mean) -> 0.08124943576780752
# *The median of the columns (area_se,compactness_mean) -> 0.09246224176978657
# *The median of the columns (area_se,concavity_mean) -> 0.09646204311152767
# *The median of the columns (area_se,concave points_mean) -> 0.09194831013916499
# *The median of the columns (area_se,symmetry_mean) -> 0.07964512268245189
# *The median of the columns (area_se,fractal_dimension_mean) -> 0.07674664455227698
# *The median of the columns (area_se,radius_se) -> 0.053434851764111446
# *The median of the columns (area_se,texture_se) -> 0.07072135785007078
# *The median of the columns (area_se,perimeter_se) -> 0.05016996484142322
# *The median of the columns (area_se,smoothness_se) -> 0.058160471275574444
# *The median of the columns (area_se,compactness_se) -> 0.07307657644125343
# *The median of the columns (area_se,concavity_se) -> 0.04586550113328325
# *The median of the columns (area_se,concave points_se) -> 0.06766433036559955
# *The median of the columns (area_se,symmetry_se) -> 0.06148696857291208
# *The median of the columns (area_se,fractal_dimension_se) -> 0.05092381465666157
# *The median of the columns (area_se,radius_worst) -> 0.08715759516186405
# *The median of the columns (area_se,texture_worst) -> 0.09450913152458545
# *The median of the columns (area_se,perimeter_worst) -> 0.08596045619801784
# *The median of the columns (area_se,area_worst) -> 0.06170494609368532
# *The median of the columns (area_se,smoothness_worst) -> 0.09031071080160041
# *The median of the columns (area_se,compactness_worst) -> 0.07648162646593859
# *The median of the columns (area_se,concavity_worst) -> 0.09528753993610228
# *The median of the columns (area_se,concave points_worst) -> 0.11711340206185566
# *The median of the columns (area_se,symmetry_worst) -> 0.06984690778979769
# *The median of the columns (area_se,fractal_dimension_worst) -> 0.06256291253382623
# *The median of the columns (smoothness_se,radius_mean) -> 0.13159864539237198
# *The median of the columns (smoothness_se,texture_mean) -> 0.13257640140055071
# *The median of the columns (smoothness_se,perimeter_mean) -> 0.13131862528469934
# *The median of the columns (smoothness_se,area_mean) -> 0.11318529106697062
# *The median of the columns (smoothness_se,smoothness_mean) -> 0.13054076013360993
# *The median of the columns (smoothness_se,compactness_mean) -> 0.1353904668425251
# *The median of the columns (smoothness_se,concavity_mean) -> 0.1409437762065231
# *The median of the columns (smoothness_se,concave points_mean) -> 0.1376739562624255
# *The median of the columns (smoothness_se,symmetry_mean) -> 0.1313131313131315
# *The median of the columns (smoothness_se,fractal_dimension_mean) -> 0.12502688085126568
# *The median of the columns (smoothness_se,radius_se) -> 0.08426579757378239
# *The median of the columns (smoothness_se,texture_se) -> 0.11561342081109566
# *The median of the columns (smoothness_se,perimeter_se) -> 0.08043160721858356
# *The median of the columns (smoothness_se,area_se) -> 0.058160471275574444
# *The median of the columns (smoothness_se,compactness_se) -> 0.11594027620069836
# *The median of the columns (smoothness_se,concavity_se) -> 0.07623853004670228
# *The median of the columns (smoothness_se,concave points_se) -> 0.11211204405615804
# *The median of the columns (smoothness_se,symmetry_se) -> 0.10602712717136353
# *The median of the columns (smoothness_se,fractal_dimension_se) -> 0.08415903154927246
# *The median of the columns (smoothness_se,radius_worst) -> 0.12857047269136446
# *The median of the columns (smoothness_se,texture_worst) -> 0.14179104477611948
# *The median of the columns (smoothness_se,perimeter_worst) -> 0.12899048757408232
# *The median of the columns (smoothness_se,area_worst) -> 0.1033813806545501
# *The median of the columns (smoothness_se,smoothness_worst) -> 0.13278036509501295
# *The median of the columns (smoothness_se,compactness_worst) -> 0.1243650736386967
# *The median of the columns (smoothness_se,concavity_worst) -> 0.14225239616613422
# *The median of the columns (smoothness_se,concave points_worst) -> 0.16024747594928096
# *The median of the columns (smoothness_se,symmetry_worst) -> 0.11323384437570111
# *The median of the columns (smoothness_se,fractal_dimension_worst) -> 0.11228201380154318
# *The median of the columns (compactness_se,radius_mean) -> 0.15145061290169926
# *The median of the columns (compactness_se,texture_mean) -> 0.15363613115839414
# *The median of the columns (compactness_se,perimeter_mean) -> 0.15141046054015073
# *The median of the columns (compactness_se,area_mean) -> 0.1311016618507998
# *The median of the columns (compactness_se,smoothness_mean) -> 0.14940868466191226
# *The median of the columns (compactness_se,compactness_mean) -> 0.15666776819779493
# *The median of the columns (compactness_se,concavity_mean) -> 0.15907683423163443
# *The median of the columns (compactness_se,concave points_mean) -> 0.15606527566358996
# *The median of the columns (compactness_se,symmetry_mean) -> 0.14975816384774843
# *The median of the columns (compactness_se,fractal_dimension_mean) -> 0.14765524078469072
# *The median of the columns (compactness_se,radius_se) -> 0.10065490760565654
# *The median of the columns (compactness_se,texture_se) -> 0.13336087993286627
# *The median of the columns (compactness_se,perimeter_se) -> 0.09627808748492028
# *The median of the columns (compactness_se,area_se) -> 0.07307657644125343
# *The median of the columns (compactness_se,smoothness_se) -> 0.11594027620069836
# *The median of the columns (compactness_se,concavity_se) -> 0.0912297819726996
# *The median of the columns (compactness_se,concave points_se) -> 0.13180774107985854
# *The median of the columns (compactness_se,symmetry_se) -> 0.12044802161310297
# ...
# *The median of the columns (concave points_worst,texture_worst) -> 0.2676357168502114
# *The median of the columns (concave points_worst,perimeter_worst) -> 0.23959659345584944
# *The median of the columns (concave points_worst,area_worst) -> 0.1773195774939088
# *The median of the columns (concave points_worst,smoothness_worst) -> 0.2494493185582668
# *The median of the columns (concave points_worst,compactness_worst) -> 0.228882815939008
# *The median of the columns (concave points_worst,concavity_worst) -> 0.24816598596884165
# *The median of the columns (concave points_worst,symmetry_worst) -> 0.191799724029174
# *The median of the columns (concave points_worst,fractal_dimension_worst) -> 0.18929555293191674
# *The median of the columns (symmetry_worst,radius_mean) -> 0.15248481078707216
# *The median of the columns (symmetry_worst,texture_mean) -> 0.15533215060122219
# *The median of the columns (symmetry_worst,perimeter_mean) -> 0.1520442817430644
# *The median of the columns (symmetry_worst,area_mean) -> 0.1317560394486521
# *The median of the columns (symmetry_worst,smoothness_mean) -> 0.1501309018687369
# *The median of the columns (symmetry_worst,compactness_mean) -> 0.15752496224891444
# *The median of the columns (symmetry_worst,concavity_mean) -> 0.16126957849326728
# *The median of the columns (symmetry_worst,concave points_mean) -> 0.15619153206132808
# *The median of the columns (symmetry_worst,symmetry_mean) -> 0.1513897102306328
# *The median of the columns (symmetry_worst,fractal_dimension_mean) -> 0.14902424600827913
# *The median of the columns (symmetry_worst,radius_se) -> 0.09928546748166606
# *The median of the columns (symmetry_worst,texture_se) -> 0.13621131480386367
# *The median of the columns (symmetry_worst,perimeter_se) -> 0.09384525762718388
# *The median of the columns (symmetry_worst,area_se) -> 0.06984690778979769
# *The median of the columns (symmetry_worst,smoothness_se) -> 0.11323384437570111
# *The median of the columns (symmetry_worst,compactness_se) -> 0.13293477934328723
# *The median of the columns (symmetry_worst,concavity_se) -> 0.0898876404494382
# *The median of the columns (symmetry_worst,concave points_se) -> 0.13320704678916456
# *The median of the columns (symmetry_worst,symmetry_se) -> 0.11919201917996025
# *The median of the columns (symmetry_worst,fractal_dimension_se) -> 0.09611265425700988
# *The median of the columns (symmetry_worst,radius_worst) -> 0.14886288785650525
# *The median of the columns (symmetry_worst,texture_worst) -> 0.1669623496944609
# *The median of the columns (symmetry_worst,perimeter_worst) -> 0.14882712398974968
# *The median of the columns (symmetry_worst,area_worst) -> 0.11893411345748078
# *The median of the columns (symmetry_worst,smoothness_worst) -> 0.15296668637886857
# *The median of the columns (symmetry_worst,compactness_worst) -> 0.1474472698600433
# *The median of the columns (symmetry_worst,concavity_worst) -> 0.16439976345357776
# *The median of the columns (symmetry_worst,concave points_worst) -> 0.191799724029174
# *The median of the columns (symmetry_worst,fractal_dimension_worst) -> 0.13148038635915632
# *The median of the columns (fractal_dimension_worst,radius_mean) -> 0.15282697100878917
# *The median of the columns (fractal_dimension_worst,texture_mean) -> 0.15537565838854006
# *The median of the columns (fractal_dimension_worst,perimeter_mean) -> 0.15230460921843703
# *The median of the columns (fractal_dimension_worst,area_mean) -> 0.12987674043877662
# *The median of the columns (fractal_dimension_worst,smoothness_mean) -> 0.14931840751105918
# *The median of the columns (fractal_dimension_worst,compactness_mean) -> 0.1578118850846123
# *The median of the columns (fractal_dimension_worst,concavity_mean) -> 0.15879574970484056
# *The median of the columns (fractal_dimension_worst,concave points_mean) -> 0.1563121272365806
# *The median of the columns (fractal_dimension_worst,symmetry_mean) -> 0.15043945953036852
# *The median of the columns (fractal_dimension_worst,fractal_dimension_mean) -> 0.14736007102170845
# *The median of the columns (fractal_dimension_worst,radius_se) -> 0.09753377935196123
# *The median of the columns (fractal_dimension_worst,texture_se) -> 0.13228295232120613
# *The median of the columns (fractal_dimension_worst,perimeter_se) -> 0.09146915927081528
# *The median of the columns (fractal_dimension_worst,area_se) -> 0.06256291253382623
# *The median of the columns (fractal_dimension_worst,smoothness_se) -> 0.11228201380154318
# *The median of the columns (fractal_dimension_worst,compactness_se) -> 0.13065722156631254
# *The median of the columns (fractal_dimension_worst,concavity_se) -> 0.08611373475009843
# *The median of the columns (fractal_dimension_worst,concave points_se) -> 0.13009750280411048
# *The median of the columns (fractal_dimension_worst,symmetry_se) -> 0.11833736702876119
# *The median of the columns (fractal_dimension_worst,fractal_dimension_se) -> 0.0953609372546475
# *The median of the columns (fractal_dimension_worst,radius_worst) -> 0.1472785485592315
# *The median of the columns (fractal_dimension_worst,texture_worst) -> 0.16246884428702624
# *The median of the columns (fractal_dimension_worst,perimeter_worst) -> 0.147317329135511
# *The median of the columns (fractal_dimension_worst,area_worst) -> 0.11747935509241053
# *The median of the columns (fractal_dimension_worst,smoothness_worst) -> 0.15367965367965375
# *The median of the columns (fractal_dimension_worst,compactness_worst) -> 0.14465756614372616
# *The median of the columns (fractal_dimension_worst,concavity_worst) -> 0.160751691429879
# *The median of the columns (fractal_dimension_worst,concave points_worst) -> 0.18929555293191674
# *The median of the columns (fractal_dimension_worst,symmetry_worst) -> 0.13148038635915632
#
#  ---> Correlation matrix :
#
# [[0.1798476  0.18461352 0.17812104 0.15278897 0.17558805 0.18722778
#   0.18430178 0.19070577 0.17511477 0.1783909  0.11095986 0.15527758
#   0.10592201 0.0842444  0.13159865 0.15145061 0.10034226 0.15381701
#   0.14026035 0.10550972 0.1775169  0.1997255  0.17558805 0.14147377
#   0.18587583 0.17354119 0.19422752 0.2395189  0.15248481 0.15282697]
#  [0.18461352 0.19005749 0.18347845 0.15748112 0.18227934 0.19431323
#   0.18982725 0.19466241 0.17985503 0.18381326 0.11305189 0.16199611
#   0.10652689 0.08623605 0.1325764  0.15363613 0.1005303  0.15871093
#   0.14221734 0.10595885 0.18285308 0.20508066 0.18127436 0.14436337
#   0.19276294 0.18058843 0.1985465  0.23950428 0.15533215 0.15537566]
#  [0.17812104 0.18347845 0.17566167 0.1523347  0.17331214 0.18722778
#   0.18334114 0.19070577 0.17380117 0.17732569 0.11214919 0.15494936
#   0.10776045 0.08361551 0.13131863 0.15141046 0.10213531 0.15381701
#   0.13917245 0.1069321  0.17545436 0.20309168 0.17331214 0.14009182
#   0.18556429 0.17275931 0.19443341 0.24086091 0.15204428 0.15230461]
#  [0.15278897 0.15748112 0.1523347  0.13005302 0.15028632 0.15905666
#   0.16241799 0.15749735 0.15134677 0.14811315 0.09996483 0.13275725
#   0.09366055 0.07090053 0.11318529 0.13110166 0.08903871 0.13083198
#   0.11833737 0.09633086 0.14761594 0.17340403 0.14788473 0.11762908
#   0.15342171 0.14502096 0.16629393 0.2067136  0.13175604 0.12987674]
#  [0.17558805 0.18227934 0.17331214 0.15028632 0.17152659 0.18656346
#   0.1826851  0.18839366 0.17206825 0.1741786  0.10936085 0.15246248
#   0.10419923 0.08124944 0.13054076 0.14940868 0.09746241 0.15206499
#   0.13888359 0.10345761 0.17206825 0.1966951  0.17026271 0.13956848
#   -1.06713879e-01  6.10918015e-02 -2.06498810e-01  2.22918950e-02
#   -1.10216409e-01 -6.44482485e-01]
#  [ 1.70202688e-01  1.91087585e-01 -9.18216185e-02 -2.15785760e-01
#    1.22106316e-01 -1.50724490e-01  3.35324568e-01  7.14532698e-02
#    1.19733219e-01 -2.54224969e-01  4.10152945e-01 -1.10048411e-02
#   -1.60048546e-01 -1.14225004e-01  1.07102143e-01  3.57065663e-01
#   -1.29665015e-01 -2.32089663e-01 -1.05055296e-01  2.31255033e-01
#   -1.42494228e-01 -1.60466561e-02 -4.58973875e-02  9.88275415e-02
#    2.25364936e-01 -2.33458261e-01 -8.85508068e-02  1.30246596e-01
#   -4.05661290e-02 -5.52395227e-03]
#  [ 1.68094311e-01  1.64291184e-01 -2.45980348e-01 -1.44385612e-01
#    3.16301197e-02  1.55567158e-01 -6.47519526e-02 -1.84573894e-01
#   -5.71931234e-02  5.19935985e-01  2.73758050e-01  1.92342895e-02
#   -1.56516260e-01 -2.93299355e-03  2.14996526e-01  8.00896636e-02
#    3.55484686e-02  1.61077759e-02  2.71591836e-01 -1.66248733e-01
#   -9.29996801e-02 -2.22234515e-02 -1.82748578e-01  1.21145301e-01
#   -1.98296741e-02  1.54862281e-01  3.77747046e-01 -2.06043993e-02
#   -2.13623909e-01 -2.46467011e-02]]
#
# Explained variance             : [ 9.871e+01  1.680e+00  5.000e-01  3.600e-01  2.600e-01  2.100e-01
#   1.900e-01  1.300e-01  1.000e-01  8.000e-02  6.000e-02  5.000e-02
#   3.000e-02  3.000e-02  2.000e-02  1.000e-02 -1.000e-02 -2.000e-02
#  -3.000e-02 -3.000e-02 -4.000e-02 -6.000e-02 -7.000e-02 -9.000e-02
#  -1.100e-01 -1.200e-01 -1.900e-01 -3.200e-01 -6.300e-01 -7.100e-01]
# Cumulative explained variance  : [ 98.71 100.39 100.89 101.25 101.51 101.72 101.91 102.04 102.14 102.22
#  102.28 102.33 102.36 102.39 102.41 102.42 102.41 102.39 102.36 102.33
#  102.29 102.23 102.16 102.07 101.96 101.84 101.65 101.33 100.7   99.99]

# %%
# Data Transformation.

# Select 'k' no of eigen vectors
k = 5
W = eigenvectors[:, :k] # Projection matrix

# Transform the original dataset
X_proj = x.dot(W)
X_proj_fin = pd.concat([X_proj, cat_data], axis=1)
print('\nNew projection:')
print(X_proj_fin)
#X_proj_pd = pd.DataFrame(X_proj)
#print(X_proj)

sns.pairplot(data=X_proj_fin, hue='diagnosis', height=2, palette="Set1")
plt.plot()
# Out:
# New projection:
#             0         1         2         3         4        id diagnosis
# 0   -0.160821 -1.292318 -0.236244  0.094870 -0.401356    842302         M
# 1   -2.128089 -1.561701 -0.007862 -0.967749 -0.086540    842517         M
# 2   -1.050714 -1.597474 -0.152744 -0.496035 -0.205040  84300903         M
# 3    0.029325 -1.005417 -1.624313  0.509689  0.302629  84348301         M
# 4   -1.779131 -1.154955  0.092035 -0.398568 -0.446087  84358402         M
# ..        ...       ...       ...       ...       ...       ...       ...
# 564 -1.075588 -1.507947  0.444961 -0.471000 -0.410858    926424         M
# 565 -1.532946 -1.538945  0.005652 -0.657452  0.080475    926682         M
# 566 -2.302746 -1.443675 -0.289372 -0.382495  0.288513    926954         M
# 567  0.592071 -1.795654 -0.494250 -0.036525  0.023516    927241         M
# 568 -4.178375 -0.743501 -0.681307 -0.175498  0.463953     92751         B
#
# [569 rows x 7 columns]
# []

# %%
# Calculate the end points of the PC axes (scaled by the square root of the absolute eigenvalues)
#pc_endpoints = eigenvectors * np.sqrt(np.abs(eigenvalues))
  
#def Original():
    
    # Set the figure size
    #plt.figure(figsize=(8, 8))

    #df = pd.DataFrame(X_proj_fin)

    # Plot the DataFrame using Seaborn's scatterplot function
    #sns.scatterplot(x=X_proj_fin[0], y=X_proj_fin[1],hue = X_proj_fin['Wine'],style=X_proj_fin['Wine'],palette="Set1", data=df)

    # Show the plot
    #plt.xlabel('Feature 1')
    #plt.ylabel('Feature 2')
    #plt.title('Transformed Data')
    #plt.grid(True)
    #plt.axis('equal')
    #plt.show()
    

#Original()
#Transformed()

# %%
X_proj_1D = X_proj.to_numpy()
#X_proj_1D = X_proj.flatten()[::-1]

# Calculate the condensed distance matrix
condensed_dist_matrix = pdist(X_proj_1D)

# Convert the condensed distance matrix to a square distance matrix
dist_matrix = pd.DataFrame(squareform(condensed_dist_matrix))

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(dist_matrix, cmap='Greys', annot=False, annot_kws={"size": 10})

title_fontsize = 5
label_fontsize = 5

plt.title('Heatmap', fontsize=title_fontsize)
plt.xlabel('Projection - X axis', fontsize=label_fontsize)
plt.ylabel('Projection - Y axis', fontsize=label_fontsize)

ax = plt.gca()
ax.tick_params(axis='x', labelsize=label_fontsize)
ax.tick_params(axis='y', labelsize=label_fontsize)

plt.show()

# %%
# Create a color mapping based on the species
species_color_mapping = X_proj_fin['Wine'].map({1: 'blue', 2: 'orange', 3: 'green'})

# Create a clustermap using the distance matrix and fastcluster with matching colors
linkage_matrix = fastcluster.linkage(condensed_dist_matrix, method='ward')
sns.clustermap(dist_matrix, cmap='viridis', figsize=(8, 8), row_linkage=linkage_matrix, col_linkage=linkage_matrix,
               row_colors=species_color_mapping, col_colors=species_color_mapping)

# Show the plot
plt.title('Distance Matrix Heatmap with Matching Colors')
plt.show()

# %%
# Create a custom color mapping based on the species
species_color_mapping = X_proj_fin['Wine'].map({1: 'blue', 2: 'orange', 3: 'green'})

# Plot the distance matrix heatmap with colored labels
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(dist_matrix, cmap='viridis', ax=ax,
            cbar_kws={'label': 'Distance'})

# Set the tick labels and colors
ax.set_xticks(np.arange(dist_matrix.shape[0]) + 0.5)
ax.set_yticks(np.arange(dist_matrix.shape[0]) + 0.5)
ax.set_xticklabels(species_color_mapping.index, rotation=90, fontsize=6)
ax.set_yticklabels(species_color_mapping.index, rotation=0, fontsize=6)

# Color the tick labels
for tick, color in zip(ax.get_xticklabels(), species_color_mapping):
    tick.set_color(color)

for tick, color in zip(ax.get_yticklabels(), species_color_mapping):
    tick.set_color(color)

# Show the plot
plt.title('Distance Matrix Heatmap with Colored Labels')
plt.show()

# %%
# Dump to CSV

dist_matrix.to_csv('COMAD_3_dim.csv', index=False)
