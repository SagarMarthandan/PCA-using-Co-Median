# %%
# Import Modules

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
import seaborn as sns
import statistics
import fastcluster
from scipy import stats
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from mpl_toolkits.mplot3d import Axes3D
from itertools import combinations
from itertools import permutations
from scipy.spatial.distance import pdist, squareform
from mpl_toolkits.mplot3d import Axes3D

# %%
wine = pd.read_csv('wine.csv')
wine_noindex = pd.read_csv('wine.csv', index_col=False)  
#print(f'\t*Wine-Original : \n\n{wine.head()}')
wine_columns = wine.columns

categorical_features = ['Wine']
numerical_features = ['Alcohol', 'Malic.acid', 'Ash', 'Acl', 'Mg', 'Phenols', 'Flavanoids', 'Nonflavanoid.phenols', 'Proanth', 'Color.int', 'Hue','OD', 'Proline']
cat_data = wine_noindex[categorical_features]

scaler = MinMaxScaler(feature_range=(-1, 1))
x = pd.DataFrame(scaler.fit_transform(wine_noindex[numerical_features]))
x.columns = numerical_features
x_comb = pd.concat([cat_data, x], axis=1)
print(f'\n----> SCALED DATASET : \n\n{x_comb}')
s_row, s_col = x.shape

s_row, s_col = x.shape
print(f'\n*\tSamples : {s_row}, Dimensions : {len(wine.columns)}')

#sns.pairplot(data=x_comb, hue='Wine', height=2)
#plt.plot()
# Out:
# ----> SCALED DATASET :
#
#      Wine   Alcohol  Malic.acid       Ash       Acl        Mg   Phenols  \
# 0       1  0.684211   -0.616601  0.144385 -0.484536  0.239130  0.255172
# 1       1  0.142105   -0.588933 -0.165775 -0.938144 -0.347826  0.151724
# 2       1  0.121053   -0.359684  0.401070 -0.175258 -0.326087  0.255172
# 3       1  0.757895   -0.521739  0.219251 -0.360825 -0.065217  0.979310
# 4       1  0.163158   -0.268775  0.614973  0.072165  0.043478  0.255172
# ..    ...       ...         ...       ...       ...       ...       ...
# 173     3  0.410526    0.940711  0.165775  0.020619 -0.456522 -0.517241
# 174     3  0.247368    0.252964  0.197861  0.278351 -0.304348 -0.434483
# 175     3  0.178947    0.399209 -0.037433 -0.030928  0.086957 -0.579310
# 176     3  0.126316   -0.268775  0.080214 -0.030928  0.086957 -0.537931
# 177     3  0.631579    0.328063  0.475936  0.432990 -0.434783 -0.262069
#
#      Flavanoids  Nonflavanoid.phenols   Proanth  Color.int       Hue  \
# 0      0.147679             -0.433962  0.186120  -0.255973 -0.089431
# 1      0.021097             -0.509434 -0.451104  -0.470990 -0.073171
# 2      0.223629             -0.358491  0.514196  -0.249147 -0.105691
# 3      0.329114             -0.584906  0.116719   0.112628 -0.382114
# 4     -0.008439             -0.018868 -0.110410  -0.481229 -0.089431
# ..          ...                   ...       ...        ...       ...
# 173   -0.886076              0.471698 -0.589905   0.095563 -0.739837
# 174   -0.827004              0.132075 -0.369085   0.027304 -0.642276
# 175   -0.852321              0.132075 -0.406940   0.522184 -0.821138
# 176   -0.856540              0.509434 -0.337539   0.368601 -0.804878
# 177   -0.822785              0.622642 -0.406940   0.351536 -0.788618
#
#            OD   Proline
# 0    0.941392  0.122682
# 1    0.560440  0.101284
# 2    0.391941  0.293866
# 3    0.597070  0.714693
# 4    0.216117 -0.348074
# ..        ...       ...
# 173 -0.655678 -0.340942
# 174 -0.787546 -0.326676
# 175 -0.787546 -0.205421
# 176 -0.743590 -0.198288
# 177 -0.758242 -0.597718
#
# [178 rows x 14 columns]
#
# *	Samples : 178, Dimensions : 14

# %%
## ----------- MEDIAN ABSOLUTE DEVIATION (MAD) correlation matrix ---------------

def compute_median_absolute_deviation(df):
    return df.apply(lambda col: np.absolute(col - col.median()))

def generate_corr_elems(columns):
    comb = permutations(columns, 2)
    perms = list(comb)
    diag = [(col, col) for col in columns]
    return diag + perms

def compute_corr_matrix_values(df, corr_elems):
    corr_values = []
    for elem in corr_elems:
        corr_values.append(df[elem[0]].append(df[elem[1]], ignore_index=True).median(axis=0))
    return corr_values

def construct_corr_matrix(corr_values, num_columns):
    matrix = np.diag(corr_values[:num_columns])
    k = 0
    for i in range(num_columns):
        for j in range(num_columns):
            if i != j:
                matrix[i, j] = corr_values[num_columns:][k]
                k += 1
    return matrix

# Compute the Median Absolute Deviation
x_MAD = compute_median_absolute_deviation(x)
print(f'\n ---> Median Absolute Deviation : \n\n{x_MAD}')

# Generate the correlation matrix elements
corr_elems = generate_corr_elems(x_MAD.columns)
print(f'\n ---> The elements of the corr matrix are : \n\n{corr_elems}')

# Compute the correlation matrix values
corr_values = compute_corr_matrix_values(x_MAD, corr_elems)
print(f'\n ---> The values of the corr_elems are : \n')
for i, value in zip(corr_elems, corr_values):
    print(f'*The median of the columns ({i[0]},{i[1]}) -> {value}')

# Construct the correlation matrix
corr_matrix = construct_corr_matrix(corr_values, x_MAD.shape[1])
print(f'\n ---> Correlation matrix : \n\n{corr_matrix}')
# Out:
#  ---> Median Absolute Deviation :
#
#       Alcohol  Malic.acid       Ash       Acl        Mg   Phenols  Flavanoids  \
# 0    0.621053    0.061265  0.074866  0.402062  0.630435  0.306897    0.390295
# 1    0.078947    0.033597  0.235294  0.855670  0.043478  0.203448    0.263713
# 2    0.057895    0.195652  0.331551  0.092784  0.065217  0.306897    0.466245
# 3    0.694737    0.033597  0.149733  0.278351  0.326087  1.031034    0.571730
# 4    0.100000    0.286561  0.545455  0.154639  0.434783  0.306897    0.234177
# ..        ...         ...       ...       ...       ...       ...         ...
# 173  0.347368    1.496047  0.096257  0.103093  0.065217  0.465517    0.643460
# 174  0.184211    0.808300  0.128342  0.360825  0.086957  0.382759    0.584388
# 175  0.115789    0.954545  0.106952  0.051546  0.478261  0.527586    0.609705
# 176  0.063158    0.286561  0.010695  0.051546  0.478261  0.486207    0.613924
# 177  0.568421    0.883399  0.406417  0.515464  0.043478  0.210345    0.580169
#
#      Nonflavanoid.phenols   Proanth  Color.int       Hue        OD   Proline
# 0                0.226415  0.463722   0.162116  0.121951  0.835165  0.558488
# 1                0.301887  0.173502   0.052901  0.138211  0.454212  0.537090
# 2                0.150943  0.791798   0.168942  0.105691  0.285714  0.729672
# 3                0.377358  0.394322   0.530717  0.170732  0.490842  1.150499
# 4                0.188679  0.167192   0.063140  0.121951  0.109890  0.087732
# ..                    ...       ...        ...       ...       ...       ...
# 173              0.679245  0.312303   0.513652  0.528455  0.761905  0.094864
# 174              0.339623  0.091483   0.445392  0.430894  0.893773  0.109130
# 175              0.339623  0.129338   0.940273  0.609756  0.893773  0.230385
# 176              0.716981  0.059937   0.786689  0.593496  0.849817  0.237518
# 177              0.830189  0.129338   0.769625  0.577236  0.864469  0.161912
#
# [178 rows x 13 columns]
#
#  ---> The elements of the corr matrix are :
#
# [('Alcohol', 'Alcohol'), ('Malic.acid', 'Malic.acid'), ('Ash', 'Ash'), ('Acl', 'Acl'), ('Mg', 'Mg'), ('Phenols', 'Phenols'), ('Flavanoids', 'Flavanoids'), ('Nonflavanoid.phenols', 'Nonflavanoid.phenols'), ('Proanth', 'Proanth'), ('Color.int', 'Color.int'), ('Hue', 'Hue'), ('OD', 'OD'), ('Proline', 'Proline'), ('Alcohol', 'Malic.acid'), ('Alcohol', 'Ash'), ('Alcohol', 'Acl'), ('Alcohol', 'Mg'), ('Alcohol', 'Phenols'), ('Alcohol', 'Flavanoids'), ('Alcohol', 'Nonflavanoid.phenols'), ('Alcohol', 'Proanth'), ('Alcohol', 'Color.int'), ('Alcohol', 'Hue'), ('Alcohol', 'OD'), ('Alcohol', 'Proline'), ('Malic.acid', 'Alcohol'), ('Malic.acid', 'Ash'), ('Malic.acid', 'Acl'), ('Malic.acid', 'Mg'), ('Malic.acid', 'Phenols'), ('Malic.acid', 'Flavanoids'), ('Malic.acid', 'Nonflavanoid.phenols'), ('Malic.acid', 'Proanth'), ('Malic.acid', 'Color.int'), ('Malic.acid', 'Hue'), ('Malic.acid', 'OD'), ('Malic.acid', 'Proline'), ('Ash', 'Alcohol'), ('Ash', 'Malic.acid'), ('Ash', 'Acl'), ('Ash', 'Mg'), ('Ash', 'Phenols'), ('Ash', 'Flavanoids'), ('Ash', 'Nonflavanoid.phenols'), ('Ash', 'Proanth'), ('Ash', 'Color.int'), ('Ash', 'Hue'), ('Ash', 'OD'), ('Ash', 'Proline'), ('Acl', 'Alcohol'), ('Acl', 'Malic.acid'), ('Acl', 'Ash'), ('Acl', 'Mg'), ('Acl', 'Phenols'), ('Acl', 'Flavanoids'), ('Acl', 'Nonflavanoid.phenols'), ('Acl', 'Proanth'), ('Acl', 'Color.int'), ('Acl', 'Hue'), ('Acl', 'OD'), ('Acl', 'Proline'), ('Mg', 'Alcohol'), ('Mg', 'Malic.acid'), ('Mg', 'Ash'), ('Mg', 'Acl'), ('Mg', 'Phenols'), ('Mg', 'Flavanoids'), ('Mg', 'Nonflavanoid.phenols'), ('Mg', 'Proanth'), ('Mg', 'Color.int'), ('Mg', 'Hue'), ('Mg', 'OD'), ('Mg', 'Proline'), ('Phenols', 'Alcohol'), ('Phenols', 'Malic.acid'), ('Phenols', 'Ash'), ('Phenols', 'Acl'), ('Phenols', 'Mg'), ('Phenols', 'Flavanoids'), ('Phenols', 'Nonflavanoid.phenols'), ('Phenols', 'Proanth'), ('Phenols', 'Color.int'), ('Phenols', 'Hue'), ('Phenols', 'OD'), ('Phenols', 'Proline'), ('Flavanoids', 'Alcohol'), ('Flavanoids', 'Malic.acid'), ('Flavanoids', 'Ash'), ('Flavanoids', 'Acl'), ('Flavanoids', 'Mg'), ('Flavanoids', 'Phenols'), ('Flavanoids', 'Nonflavanoid.phenols'), ('Flavanoids', 'Proanth'), ('Flavanoids', 'Color.int'), ('Flavanoids', 'Hue'), ('Flavanoids', 'OD'), ('Flavanoids', 'Proline'), ('Nonflavanoid.phenols', 'Alcohol'), ('Nonflavanoid.phenols', 'Malic.acid'), ('Nonflavanoid.phenols', 'Ash'), ('Nonflavanoid.phenols', 'Acl'), ('Nonflavanoid.phenols', 'Mg'), ('Nonflavanoid.phenols', 'Phenols'), ('Nonflavanoid.phenols', 'Flavanoids'), ('Nonflavanoid.phenols', 'Proanth'), ('Nonflavanoid.phenols', 'Color.int'), ('Nonflavanoid.phenols', 'Hue'), ('Nonflavanoid.phenols', 'OD'), ('Nonflavanoid.phenols', 'Proline'), ('Proanth', 'Alcohol'), ('Proanth', 'Malic.acid'), ('Proanth', 'Ash'), ('Proanth', 'Acl'), ('Proanth', 'Mg'), ('Proanth', 'Phenols'), ('Proanth', 'Flavanoids'), ('Proanth', 'Nonflavanoid.phenols'), ('Proanth', 'Color.int'), ('Proanth', 'Hue'), ('Proanth', 'OD'), ('Proanth', 'Proline'), ('Color.int', 'Alcohol'), ('Color.int', 'Malic.acid'), ('Color.int', 'Ash'), ('Color.int', 'Acl'), ('Color.int', 'Mg'), ('Color.int', 'Phenols'), ('Color.int', 'Flavanoids'), ('Color.int', 'Nonflavanoid.phenols'), ('Color.int', 'Proanth'), ('Color.int', 'Hue'), ('Color.int', 'OD'), ('Color.int', 'Proline'), ('Hue', 'Alcohol'), ('Hue', 'Malic.acid'), ('Hue', 'Ash'), ('Hue', 'Acl'), ('Hue', 'Mg'), ('Hue', 'Phenols'), ('Hue', 'Flavanoids'), ('Hue', 'Nonflavanoid.phenols'), ('Hue', 'Proanth'), ('Hue', 'Color.int'), ('Hue', 'OD'), ('Hue', 'Proline'), ('OD', 'Alcohol'), ('OD', 'Malic.acid'), ('OD', 'Ash'), ('OD', 'Acl'), ('OD', 'Mg'), ('OD', 'Phenols'), ('OD', 'Flavanoids'), ('OD', 'Nonflavanoid.phenols'), ('OD', 'Proanth'), ('OD', 'Color.int'), ('OD', 'Hue'), ('OD', 'Proline'), ('Proline', 'Alcohol'), ('Proline', 'Malic.acid'), ('Proline', 'Ash'), ('Proline', 'Acl'), ('Proline', 'Mg'), ('Proline', 'Phenols'), ('Proline', 'Flavanoids'), ('Proline', 'Nonflavanoid.phenols'), ('Proline', 'Proanth'), ('Proline', 'Color.int'), ('Prolin ...
#
#  ---> The values of the corr_elems are :
#
# *The median of the columns (Alcohol,Alcohol) -> 0.3578947368421055
# *The median of the columns (Malic.acid,Malic.acid) -> 0.2055335968379447
# *The median of the columns (Ash,Ash) -> 0.17112299465240577
# *The median of the columns (Acl,Acl) -> 0.21134020618556704
# *The median of the columns (Mg,Mg) -> 0.21739130434782572
# *The median of the columns (Phenols,Phenols) -> 0.34827586206896544
# *The median of the columns (Flavanoids,Flavanoids) -> 0.35232067510548526
# *The median of the columns (Nonflavanoid.phenols,Nonflavanoid.phenols) -> 0.32075471698113206
# *The median of the columns (Proanth,Proanth) -> 0.23974763406940047
# *The median of the columns (Color.int,Color.int) -> 0.2576791808873721
# *The median of the columns (Hue,Hue) -> 0.2682926829268292
# *The median of the columns (OD,OD) -> 0.38095238095238115
# *The median of the columns (Proline,Proline) -> 0.28887303851640517
# *The median of the columns (Alcohol,Malic.acid) -> 0.2842105263157899
# *The median of the columns (Alcohol,Ash) -> 0.2566844919786102
# *The median of the columns (Alcohol,Acl) -> 0.2789473684210515
# *The median of the columns (Alcohol,Mg) -> 0.2608695652173916
# *The median of the columns (Alcohol,Phenols) -> 0.3552631578947363
# *The median of the columns (Alcohol,Flavanoids) -> 0.3565400843881857
# *The median of the columns (Alcohol,Nonflavanoid.phenols) -> 0.3396226415094339
# *The median of the columns (Alcohol,Proanth) -> 0.2842105263157899
# *The median of the columns (Alcohol,Color.int) -> 0.3054607508532423
# *The median of the columns (Alcohol,Hue) -> 0.31707317073170727
# *The median of the columns (Alcohol,OD) -> 0.3578947368421064
# *The median of the columns (Alcohol,Proline) -> 0.3263157894736839
# *The median of the columns (Malic.acid,Alcohol) -> 0.2842105263157899
# *The median of the columns (Malic.acid,Ash) -> 0.1901302022785401
# *The median of the columns (Malic.acid,Acl) -> 0.20684772421661718
# *The median of the columns (Malic.acid,Mg) -> 0.20948616600790515
# *The median of the columns (Malic.acid,Phenols) -> 0.28458498023715406
# *The median of the columns (Malic.acid,Flavanoids) -> 0.27637130801687754
# *The median of the columns (Malic.acid,Nonflavanoid.phenols) -> 0.2727272727272726
# *The median of the columns (Malic.acid,Proanth) -> 0.21140945873492845
# *The median of the columns (Malic.acid,Color.int) -> 0.23618961540018074
# *The median of the columns (Malic.acid,Hue) -> 0.2357723577235773
# *The median of the columns (Malic.acid,OD) -> 0.28613777526820994
# *The median of the columns (Malic.acid,Proline) -> 0.24750356633380888
# *The median of the columns (Ash,Alcohol) -> 0.2566844919786102
# *The median of the columns (Ash,Malic.acid) -> 0.1901302022785401
# *The median of the columns (Ash,Acl) -> 0.20469706158002077
# *The median of the columns (Ash,Mg) -> 0.19565217391304357
# *The median of the columns (Ash,Phenols) -> 0.2566844919786102
# *The median of the columns (Ash,Flavanoids) -> 0.2566844919786093
# *The median of the columns (Ash,Nonflavanoid.phenols) -> 0.25668449197860976
# *The median of the columns (Ash,Proanth) -> 0.19873817034700314
# *The median of the columns (Ash,Color.int) -> 0.220136518771331
# *The median of the columns (Ash,Hue) -> 0.21390374331550843
# *The median of the columns (Ash,OD) -> 0.2566844919786102
# *The median of the columns (Ash,Proline) -> 0.23529411764705843
# *The median of the columns (Acl,Alcohol) -> 0.2789473684210515
# *The median of the columns (Acl,Malic.acid) -> 0.20684772421661718
# *The median of the columns (Acl,Ash) -> 0.20469706158002077
# *The median of the columns (Acl,Mg) -> 0.2169430748543255
# *The median of the columns (Acl,Phenols) -> 0.2783505154639172
# *The median of the columns (Acl,Flavanoids) -> 0.27736091174039734
# *The median of the columns (Acl,Nonflavanoid.phenols) -> 0.26415094339622636
# *The median of the columns (Acl,Proanth) -> 0.2170802302513905
# *The median of the columns (Acl,Color.int) -> 0.24402730375426618
# *The median of the columns (Acl,Hue) -> 0.2520325203252035
# *The median of the columns (Acl,OD) -> 0.28205128205128194
# *The median of the columns (Acl,Proline) -> 0.25773195876288635
# *The median of the columns (Mg,Alcohol) -> 0.2608695652173916
# *The median of the columns (Mg,Malic.acid) -> 0.20948616600790515
# *The median of the columns (Mg,Ash) -> 0.19565217391304357
# *The median of the columns (Mg,Acl) -> 0.2169430748543255
# *The median of the columns (Mg,Phenols) -> 0.2608695652173916
# *The median of the columns (Mg,Flavanoids) -> 0.2608695652173916
# *The median of the columns (Mg,Nonflavanoid.phenols) -> 0.2608695652173916
# *The median of the columns (Mg,Proanth) -> 0.21739130434782594
# *The median of the columns (Mg,Color.int) -> 0.220136518771331
# *The median of the columns (Mg,Hue) -> 0.21739130434782616
# *The median of the columns (Mg,OD) -> 0.2608695652173916
# *The median of the columns (Mg,Proline) -> 0.23832413322582657
# *The median of the columns (Phenols,Alcohol) -> 0.3552631578947363
# *The median of the columns (Phenols,Malic.acid) -> 0.28458498023715406
# *The median of the columns (Phenols,Ash) -> 0.2566844919786102
# *The median of the columns (Phenols,Acl) -> 0.2783505154639172
# *The median of the columns (Phenols,Mg) -> 0.2608695652173916
# *The median of the columns (Phenols,Flavanoids) -> 0.34827586206896544
# *The median of the columns (Phenols,Nonflavanoid.phenols) -> 0.3396226415094339
# *The median of the columns (Phenols,Proanth) -> 0.2839116719242902
# *The median of the columns (Phenols,Color.int) -> 0.306896551724138
# *The median of the columns (Phenols,Hue) -> 0.31034482758620696
# *The median of the columns (Phenols,OD) -> 0.36996336996337
# *The median of the columns (Phenols,Proline) -> 0.3163116729794875
# *The median of the columns (Flavanoids,Alcohol) -> 0.3565400843881857
# *The median of the columns (Flavanoids,Malic.acid) -> 0.27637130801687754
# *The median of the columns (Flavanoids,Ash) -> 0.2566844919786093
# *The median of the columns (Flavanoids,Acl) -> 0.27736091174039734
# *The median of the columns (Flavanoids,Mg) -> 0.2608695652173916
# *The median of the columns (Flavanoids,Phenols) -> 0.34827586206896544
# *The median of the columns (Flavanoids,Nonflavanoid.phenols) -> 0.3396226415094339
# *The median of the columns (Flavanoids,Proanth) -> 0.27637130801687754
# *The median of the columns (Flavanoids,Color.int) -> 0.3056839619245114
# *The median of the columns (Flavanoids,Hue) -> 0.31707317073170727
# *The median of the columns (Flavanoids,OD) -> 0.36075949367088606
# *The median of the columns (Flavanoids,Proline) -> 0.318830242510699
# *The median of the columns (Nonflavanoid.phenols,Alcohol) -> 0.3396226415094339
# *The median of the columns (Nonflavanoid.phenols,Malic.acid) -> 0.2727272727272726
# *The median of the columns (Nonflavanoid.phenols,Ash) -> 0.25668449197860976
# *The median of the columns (Nonflavanoid.phenols,Acl) -> 0.26415094339622636
# *The median of the columns (Nonflavanoid.phenols,Mg) -> 0.2608695652173916
# *The median of the columns (Nonflavanoid.phenols,Phenols) -> 0.3396226415094339
# *The median of the columns (Nonflavanoid.phenols,Flavanoids) -> 0.3396226415094339
# *The median of the columns (Nonflavanoid.phenols,Proanth) -> 0.26813880126182965
# *The median of the columns (Nonflavanoid.phenols,Color.int) -> 0.3018867924528301
# *The median of the columns (Nonflavanoid.phenols,Hue) -> 0.30188679245283023
# *The median of the columns (Nonflavanoid.phenols,OD) -> 0.33962264150943394
# *The median of the columns (Nonflavanoid.phenols,Proline) -> 0.30188679245283023
# *The median of the columns (Proanth,Alcohol) -> 0.2842105263157899
# *The median of the columns (Proanth,Malic.acid) -> 0.21140945873492845
# *The median of the columns (Proanth,Ash) -> 0.19873817034700314
# *The median of the columns (Proanth,Acl) -> 0.2170802302513905
# *The median of the columns (Proanth,Mg) -> 0.21739130434782594
# *The median of the columns (Proanth,Phenols) -> 0.2839116719242902
# *The median of the columns (Proanth,Flavanoids) -> 0.27637130801687754
# *The median of the columns (Proanth,Nonflavanoid.phenols) -> 0.26813880126182965
# *The median of the columns (Proanth,Color.int) -> 0.24921135646687687
# *The median of the columns (Proanth,Hue) -> 0.2520325203252035
# *The median of the columns (Proanth,OD) -> 0.2863902658855339
# *The median of the columns (Proanth,Proline) -> 0.2603727437594782
# *The median of the columns (Color.int,Alcohol) -> 0.3054607508532423
# *The median of the columns (Color.int,Malic.acid) -> 0.23618961540018074
# *The median of the columns (Color.int,Ash) -> 0.220136518771331
# *The median of the columns (Color.int,Acl) -> 0.24402730375426618
# *The median of the columns (Color.int,Mg) -> 0.220136518771331
# *The median of the columns (Color.int,Phenols) -> 0.306896551724138
# *The median of the columns (Color.int,Flavanoids) -> 0.3056839619245114
# *The median of the columns (Color.int,Nonflavanoid.phenols) -> 0.3018867924528301
# *The median of the columns (Color.int,Proanth) -> 0.24921135646687687
# *The median of the columns (Color.int,Hue) -> 0.25853242320819114
# *The median of the columns (Color.int,OD) -> 0.30769230769230793
# *The median of the columns (Color.int,Proline) -> 0.2753891320541596
# *The median of the columns (Hue,Alcohol) -> 0.31707317073170727
# *The median of the columns (Hue,Malic.acid) -> 0.2357723577235773
# *The median of the columns (Hue,Ash) -> 0.21390374331550843
# *The median of the columns (Hue,Acl) -> 0.2520325203252035
# *The median of the columns (Hue,Mg) -> 0.21739130434782616
# *The median of the columns (Hue,Phenols) -> 0.31034482758620696
# *The median of the columns (Hue,Flavanoids) -> 0.31707317073170727
# *The median of the columns (Hue,Nonflavanoid.phenols) -> 0.30188679245283023
# *The median of the columns (Hue,Proanth) -> 0.2520325203252035
# *The median of the columns (Hue,Color.int) -> 0.25853242320819114
# *The median of the columns (Hue,OD) -> 0.31707317073170727
# *The median of the columns (Hue,Proline) -> 0.27603423680456496
# *The median of the columns (OD,Alcohol) -> 0.3578947368421064
# *The median of the columns (OD,Malic.acid) -> 0.28613777526820994
# *The median of the columns (OD,Ash) -> 0.2566844919786102
# *The median of the columns (OD,Acl) -> 0.28205128205128194
# *The median of the columns (OD,Mg) -> 0.2608695652173916
# *The median of the columns (OD,Phenols) -> 0.36996336996337
# *The median of the columns (OD,Flavanoids) -> 0.36075949367088606
# *The median of the columns (OD,Nonflavanoid.phenols) -> 0.33962264150943394
# *The median of the columns (OD,Proanth) -> 0.2863902658855339
# *The median of the columns (OD,Color.int) -> 0.30769230769230793
# *The median of the columns (OD,Hue) -> 0.31707317073170727
# *The median of the columns (OD,Proline) -> 0.3291464835687376
# *The median of the columns (Proline,Alcohol) -> 0.3263157894736839
# *The median of the columns (Proline,Malic.acid) -> 0.24750356633380888
# *The median of the columns (Proline,Ash) -> 0.23529411764705843
# *The median of the columns (Proline,Acl) -> 0.25773195876288635
# *The median of the columns (Proline,Mg) -> 0.23832413322582657
# *The median of the columns (Proline,Phenols) -> 0.3163116729794875
# *The median of the columns (Proline,Flavanoids) -> 0.318830242510699
# *The median of the columns (Proline,Nonflavanoid.phenols) -> 0.30188679245283023
# *The median of the columns (Proline,Proanth) -> 0.2603727437594782
# *The median of the columns (Proline,Color.int) -> 0.2753891320541596
# *The median of the columns (Proline,Hue) -> 0.27603423680456496
# *The median of the columns (Proline,OD) -> 0.3291464835687376
#
#  ---> Correlation matrix :
#
# [[0.35789474 0.28421053 0.25668449 0.27894737 0.26086957 0.35526316
#   0.35654008 0.33962264 0.28421053 0.30546075 0.31707317 0.35789474
#   0.32631579]
#  [0.28421053 0.2055336  0.1901302  0.20684772 0.20948617 0.28458498
#   0.27637131 0.27272727 0.21140946 0.23618962 0.23577236 0.28613778
#   0.24750357]
#  [0.25668449 0.1901302  0.17112299 0.20469706 0.19565217 0.25668449
#   0.25668449 0.25668449 0.19873817 0.22013652 0.21390374 0.25668449
#   0.23529412]
#  [0.27894737 0.20684772 0.20469706 0.21134021 0.21694307 0.27835052
#   0.27736091 0.26415094 0.21708023 0.2440273  0.25203252 0.28205128
#   0.25773196]
#  [0.26086957 0.20948617 0.19565217 0.21694307 0.2173913  0.26086957
#   0.26086957 0.26086957 0.2173913  0.22013652 0.2173913  0.26086957
#   0.23832413]
#  [0.35526316 0.28458498 0.25668449 0.27835052 0.26086957 0.34827586
#   0.34827586 0.33962264 0.28391167 0.30689655 0.31034483 0.36996337
#   0.31631167]
#  [0.35654008 0.27637131 0.25668449 0.27736091 0.26086957 0.34827586
#   0.35232068 0.33962264 0.27637131 0.30568396 0.31707317 0.36075949
#   0.31883024]
#  [0.33962264 0.27272727 0.25668449 0.26415094 0.26086957 0.33962264
#   0.33962264 0.32075472 0.2681388  0.30188679 0.30188679 0.33962264
#   0.30188679]
#  [0.28421053 0.21140946 0.19873817 0.21708023 0.2173913  0.28391167
#   0.27637131 0.2681388  0.23974763 0.24921136 0.25203252 0.28639027
#   0.26037274]
#  [0.30546075 0.23618962 0.22013652 0.2440273  0.22013652 0.30689655
#   0.30568396 0.30188679 0.24921136 0.25767918 0.25853242 0.30769231
#   0.27538913]
#  [0.31707317 0.23577236 0.21390374 0.25203252 0.2173913  0.31034483
#   0.31707317 0.30188679 0.25203252 0.25853242 0.26829268 0.31707317
#   0.27603424]
#  [0.35789474 0.28613778 0.25668449 0.28205128 0.26086957 0.36996337
#   0.36075949 0.33962264 0.28639027 0.30769231 0.31707317 0.38095238
#   0.32914648]
#  [0.32631579 0.24750357 0.23529412 0.25773196 0.23832413 0.31631167
#   0.31883024 0.30188679 0.26037274 0.27538913 0.27603424 0.32914648
#   0.28887304]]

# %%
# Eigen Value & Eigen Vector Decomposition

# Compute the eigenvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(corr_matrix)

# Sort the eigenvalues and eigenvectors in descending order
idx = eigenvalues.argsort()[::-1]   
eigenvalues = eigenvalues[idx]
eigenvectors = eigenvectors[:,idx]

# Print the sorted eigenvalues and eigenvectors
print("Eigenvalues:")
print(eigenvalues)
print("\nEigenvectors:")
print(eigenvectors)

eig_vals_total = sum(eigenvalues)
explained_variance = [(i / eig_vals_total)*100 for i in eigenvalues]
explained_variance = np.round(explained_variance, 2)
cum_explained_variance = np.cumsum(explained_variance)
print('\nExplained variance             : {}'.format(explained_variance))

print('Cumulative explained variance  : {}'.format(cum_explained_variance))
# Out:
# Eigenvalues:
# [ 3.62391679e+00  3.75492416e-02  2.27977206e-02  1.93213020e-02
#   1.22397636e-02  8.01692270e-03  6.16206549e-03 -1.47483181e-03
#  -8.96116102e-03 -1.28327271e-02 -1.47363683e-02 -3.25521996e-02
#  -3.92675097e-02]
#
# Eigenvectors:
# [[-0.31442    -0.11282986 -0.02328875 -0.26727448 -0.07208586 -0.35403201
#   -0.58465024 -0.1751306  -0.0422208  -0.12608933  0.51026939 -0.10892716
#    0.15326028]
#  [-0.24311531 -0.05811875  0.38662052  0.17120871 -0.29391144 -0.28973608
#   -0.22520618  0.06560774 -0.1460395   0.25134612 -0.28102182  0.53123032
#   -0.29613316]
#  [-0.22478658  0.20424667  0.1437678  -0.11521712  0.11467598  0.35320536
#   -0.04733174 -0.02866372  0.48341378 -0.43399693  0.17696381  0.27002319
#   -0.45450268]
#  [-0.2459078   0.12125175 -0.07842604 -0.16520352  0.45581172  0.14759557
#    0.18098616 -0.43338423 -0.34996137  0.10985092  0.03548912  0.48858617
#    0.25834427]
#  [-0.23342378  0.75005991  0.10480858  0.25216128  0.17518144 -0.3428411
#    0.13404908  0.04774263 -0.13360155  0.035611    0.09030198 -0.30511496
#   -0.13967513]
#  [-0.31272257 -0.14323994  0.12409307  0.28640049 -0.21092543  0.03760381
#    0.0670886  -0.43016574 -0.1104216  -0.54816175 -0.38862831 -0.24079445
#    0.16470396]
#  [-0.31184657 -0.12490765  0.13784279 -0.34820005  0.16126305 -0.09508567
#    0.19573272  0.68009629 -0.22094566 -0.33525074 -0.13203389  0.01960291
#    0.17885554]
#  [-0.30065644  0.19105794  0.26662435 -0.21624274 -0.36094435  0.14034517
#    0.20320292 -0.03043241  0.45032922  0.34895092 -0.00826838 -0.04915873
#    0.48580845]
#  [-0.24998116  0.1282567  -0.77585488  0.21405188 -0.3375897  -0.08701546
#    0.07990236  0.175739    0.09118997 -0.09630338  0.01755526  0.29946898
#    0.08308881]
#  [-0.26894363  0.0215461  -0.05303037 -0.10802993 -0.3376943   0.56749494
#   -0.01571034  0.0550075  -0.50273082  0.20102922  0.17213266 -0.24712544
#   -0.29918249]
#  [-0.2730499  -0.301647   -0.20685592 -0.34944601  0.07420755 -0.34036438
#    0.39144682 -0.23902773  0.16911036  0.20889875 -0.13247263 -0.21639046
#   -0.44857617]
#  [-0.31895786 -0.42877556  0.12025072  0.60284625  0.26187619  0.07351228
#    0.17862119  0.1460516   0.12318061  0.16947632  0.40196948 -0.03874975
#    0.04834332]
#  [-0.2828411   0.02251511 -0.21136853  0.04522392  0.3923646   0.21356401
#   -0.52785404  0.11500879  0.18505853  0.25009757 -0.49226233 -0.20333044
#    0.02991203]]
#
# Explained variance             : [ 1.001e+02  1.040e+00  6.300e-01  5.300e-01  3.400e-01  2.200e-01
#   1.700e-01 -4.000e-02 -2.500e-01 -3.500e-01 -4.100e-01 -9.000e-01
#  -1.080e+00]
# Cumulative explained variance  : [100.1  101.14 101.77 102.3  102.64 102.86 103.03 102.99 102.74 102.39
#  101.98 101.08 100.  ]

# %%
# Data Transformation.

# Select 'k' no of eigen vectors
k = 6
W = eigenvectors[:, :k] # Projection matrix

# Transform the original dataset
X_proj = x.dot(W)
X_proj_fin = pd.concat([cat_data, X_proj], axis=1)
X_proj_fin.to_csv('columns_heatmap.csv', index=False)
print('\nNew projection:')
print(X_proj_fin)
#print(X_proj)

sns.pairplot(data=X_proj_fin, hue='Wine', height=2, palette="Set1")
plt.plot()
# Out:
# New projection:
#      Wine         0         1         2         3         4         5
# 0       1 -0.317955 -0.384722 -0.259243  0.622578  0.407761 -0.267049
# 1       1  0.598800 -0.795962  0.104281  0.416164  0.302982 -0.165538
# 2       1 -0.204116 -0.378624 -0.516592  0.302800  0.238257  0.168377
# 3       1 -0.637533 -0.503470 -0.252193  0.556977  0.336578  0.233177
# 4       1 -0.012623  0.027022  0.234310  0.092811  0.243064 -0.050680
# ..    ...       ...       ...       ...       ...       ...       ...
# 173     3  0.632046  0.290868  0.866819 -0.316649 -0.755200  0.167580
# 174     3  0.776788  0.471356  0.326173 -0.380420 -0.352024  0.273835
# 175     3  0.744447  0.764918  0.408781 -0.186461 -0.583051  0.360647
# 176     3  0.775347  0.882406  0.228545 -0.316008 -0.471100  0.575314
# 177     3  0.394449  0.497463  0.616475 -0.605483 -0.741265  0.538117
#
# [178 rows x 7 columns]
# []

# %%
#Calculate the end points of the PC axes (scaled by the square root of the absolute eigenvalues)
pc_endpoints = eigenvectors * np.sqrt(np.abs(eigenvalues))
  
def Original():
    
    #Set the figure size
    plt.figure(figsize=(4, 4))

    df = pd.DataFrame(X_proj_fin)

    #Plot the DataFrame using Seaborn's scatterplot function
    sns.scatterplot(x=X_proj_fin[0], y=X_proj_fin[1],hue = X_proj_fin['Wine'],style=X_proj_fin['Wine'], palette="Set1", data=df)

    #Show the plot
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.title('COMAD - Wine dataset')
    plt.grid(True)
    plt.axis('equal')
    plt.show()
    

Original()
#Transformed()

# %%
X_proj_1D = X_proj.to_numpy()
#X_proj_1D = X_proj.flatten()[::-1]

# Calculate the condensed distance matrix
condensed_dist_matrix = pdist(X_proj_1D)

# Convert the condensed distance matrix to a square distance matrix
dist_matrix = pd.DataFrame(squareform(condensed_dist_matrix))

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(dist_matrix, cmap='Greys', annot=False, annot_kws={"size": 10})

title_fontsize = 5
label_fontsize = 5

plt.title('Heatmap', fontsize=title_fontsize)
plt.xlabel('Projection - X axis', fontsize=label_fontsize)
plt.ylabel('Projection - Y axis', fontsize=label_fontsize)

ax = plt.gca()
ax.tick_params(axis='x', labelsize=label_fontsize)
ax.tick_params(axis='y', labelsize=label_fontsize)

plt.show()

# %%
# Create a color mapping based on the species
species_color_mapping = X_proj_fin['Wine'].map({1: 'red', 2: 'blue', 3: 'green'})

# Create a clustermap using the distance matrix and fastcluster with matching colors
linkage_matrix = fastcluster.linkage(condensed_dist_matrix, method='ward')
sns.clustermap(dist_matrix, cmap='viridis', figsize=(5, 5), row_linkage=linkage_matrix, col_linkage=linkage_matrix,
               row_colors=species_color_mapping, col_colors=species_color_mapping)

# Show the plot
plt.show()

# %%
# Create a custom color mapping based on the species
species_color_mapping = X_proj_fin['Wine'].map({1: 'red', 2: 'blue', 3: 'green'})

# Plot the distance matrix heatmap with colored labels
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(dist_matrix, cmap='viridis', ax=ax,
            cbar_kws={'label': 'Distance'})

# Set the tick labels and colors
ax.set_xticks(np.arange(dist_matrix.shape[0]) + 0.5)
ax.set_yticks(np.arange(dist_matrix.shape[0]) + 0.5)
ax.set_xticklabels(species_color_mapping.index, rotation=90, fontsize=6)
ax.set_yticklabels(species_color_mapping.index, rotation=0, fontsize=6)

# Color the tick labels
for tick, color in zip(ax.get_xticklabels(), species_color_mapping):
    tick.set_color(color)

for tick, color in zip(ax.get_yticklabels(), species_color_mapping):
    tick.set_color(color)

# Show the plot
plt.title('Distance Matrix Heatmap with Colored Labels')
plt.show()

# %%
# Dump to CSV

dist_matrix.to_csv('COMAD_3_dim.csv', index=False)
